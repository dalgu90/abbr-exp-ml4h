# %%
import csv
import re
import sys
import os
from collections import Counter, defaultdict
import random
import shutil

# %%
# Flags
use_header_abbr = True
use_cui_less = True

# %%
# Paths
sc13t2_dir = '../data/sc13t2/'

train_note_dir = os.path.join(sc13t2_dir, 'Task1TrainSetCorpus199/ALLREPORTS')
train_anno_dir = os.path.join(sc13t2_dir, 'Task2TrainSetSILVER2pipe-cui_and_label')
train_output_fpath = os.path.join(sc13t2_dir, 'train.tsv')
train_output_fpath2 = os.path.join(sc13t2_dir, 'train_test.tsv')
train_label_fpath = os.path.join(sc13t2_dir, 'train_cui_label.tsv')

test_note_dir = os.path.join(sc13t2_dir, 'Task1TestSetCorpus100/ALLREPORTS')
test_anno_dir = os.path.join(sc13t2_dir, 'Task2ReferenceStd_CLEFShARe2013Test_StrictAndLenientpipe')
test_output_fpath = os.path.join(sc13t2_dir, 'test.tsv')
test_label_fpath = os.path.join(sc13t2_dir, 'test_cui_label.tsv')

cui_label_fpath = os.path.join(sc13t2_dir, 'cui_label.tsv')

lrabr_fpath = '../data/LRABR'

# %% [markdown]
# ## Preparation
#
# 1. Please download the following files at https://physionet.org/content/shareclefehealth2013/1.0/
# and place it under `data`:
#     - Task1TrainSetCorpus199.zip
#     - Task1TestSetCorpus100.zip
#     - Task2TrainSetSILVER2pipe-cui_and_label.zip
#     - Task2CLEFShARe2013Test_StrictAndLenientpipe.zip
#
#
# 2. Download `LRABR` of the SPECIALIST Lexicon from the [LSG website](https://lhncbc.nlm.nih.gov/LSG/Projects/lexicon/current/web/release/) (2018AB version) and put under `data`.
#
#
# 3. Install MetaMap (2018AB) version from [Installation guide](https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/documentation/Installation.html) and [Download page](https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/run-locally/MainDownload.html)

# %%
# Extract files
# !mkdir -p ../data/sc13t2/Task1TrainSetCorpus199
# !mkdir -p ../data/sc13t2/Task1TestSetCorpus100

# !unzip -o ../data/Task1TrainSetCorpus199.zip -d ../data/sc13t2/Task1TrainSetCorpus199
# !unzip -o ../data/Task1TestSetCorpus100.zip -d ../data/sc13t2/Task1TestSetCorpus100
# !unzip -o ../data/Task2TrainSetSILVER2pipe-cui_and_label.zip -d ../data/sc13t2
# !unzip -o ../data/Task2CLEFShARe2013Test_StrictAndLenientpipe.zip -d ../data/sc13t2
# Out:
# Archive:  ../data/Task1TrainSetCorpus199.zip
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/00098-016139-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/00211-027889-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/00414-104513-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/00500-097836-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/00587-400001-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/01114-083601-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/01234-029456-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/01314-028800-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/01427-342648-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/01455-067052-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/01487-290421-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/01982-060190-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/02034-037300-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/02115-010823-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/02136-017465-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/02405-069810-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/02410-026171-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/02652-006395-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/02916-100844-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/03066-084521-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/03089-097913-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/03273-009330-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/03392-360395-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/03702-098383-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/03990-040506-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/04266-000520-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/04269-027967-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/04303-005081-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/05062-230044-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/05308-090812-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/05367-106998-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/05797-095003-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/05955-087704-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/05967-095720-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/06091-383430-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/06292-371824-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/06296-089652-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/06445-096221-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/06567-071352-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/06653-081911-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07048-294691-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07156-096163-ECHO_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07352-013977-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07429-001857-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07452-053844-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07514-025655-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07700-413490-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07726-023607-DISCHARGE_SUMMARY.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07761-036998-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07780-347384-RADIOLOGY_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07786-029701-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/07866-088203-ECG_REPORT.txt
#   inflating: ../data/sc13t2/Task1TrainSetCorpus199/ALLREPORTS/
../data/sc13t2/Task2ReferenceStd_CLEFShARe2013Test_StrictAndLenientpipe/26522-011368-DISCHARGE_SUMMARY.pipe.txt

# %% [markdown]
# ## Read notes & annotations

# %%
# Parse single line of annotation
def parse_annotation_line(l, training=True):
    temp = l.split('||')
    assert temp[1] == 'Acronym_Abbreviation'
    if training:
        if temp[2] == 'CUI-less':
#             label = None
            label = ('CUI-less', 'CUI-less')
        else:
            # label = (temp[2][6:14], temp[2][26:b-1])
            cui = temp[2][temp[2].index('[')+1:temp[2].index(']')]
            name = temp[2][temp[2].rindex('[')+1:temp[2].rindex(']')]
            label = (cui, name)
    else:
#         label = (temp[2] if temp[2] != 'CUI-less' else None,
#                  temp[5] if temp[5] != 'CUI-less' else None)
        label = (temp[2], temp[5])
    result = ((int(temp[3]), int(temp[4])), label)
    return result

# %%
# Normalize a context of one side (left or right)
def trim_context(text, left=True, max_words=128):
    text = re.sub(r'\|{2,}', '|', text)  # Remove multiple '|' into one '|'
    text = re.sub(r'\t{1,}', ' ', text)  # Remove \t
    text = re.sub(r'_{2,}', '', text)    # Remove ____
    text = re.sub(r'\n{1,}', ' ', text)  # Remove multiple linebreak
    text = re.sub(r' {2,}', ' ', text)   # Remove multiple space
    text = text.strip()
    # Include up to max_words tokens
    tokens = text.split(' ')
    cnt, temp, anon_flag = 0, [], False
    while True:
        t = tokens[cnt] if (not left) else tokens[-(cnt+1)]
        if ('[**' if (not left) else '**]') in t:
            anon_flag = True
        if ('**]' if (not left) else '[**') in t:
            anon_flag = False

        if not left:
            temp.append(t)
        else:
            temp.insert(0, t)

        cnt += 1
        if ((not anon_flag) and (cnt >= max_words)) or (cnt == len(tokens)):
            break

    return ' '.join(temp)

# %%
# Parse annotations, read corresponding notes, and extract examples
def get_examples_and_cui_labels(note_dir, anno_dir, training=True):
    examples = []  # list of examples (abbr, left, right, cui)
    cui_labels_dict = {}  # dict of cui: list(label)
    
    anno_fnames = [fname for fname in os.listdir(anno_dir) if fname.endswith('.txt')]
    anno_fnames.sort()
    print(f'{anno_dir} -> {len(anno_fnames)} annotation files found')
    
    for fname in anno_fnames:
        with open(os.path.join(anno_dir, fname), 'r') as fd:
            anno_lines = [l.strip() for l in fd.readlines() if (l and l.strip())]
            if not anno_lines:
                continue
            annos = [parse_annotation_line(l, training=training) for l in anno_lines]

        note_fname = fname[:fname.index('.')] + '.txt'
        with open(os.path.join(note_dir, note_fname), 'r', encoding='iso8859_2') as fd:
            text = fd.read()

        anno_cnt_temp = 0
        first_lb = text.index('\n')  # the position of first linebreak. the first line will not be used.
        for (s, e), label in annos:
            if (not use_cui_less) and (label is None or label[0] is None or label[0] == 'CUI-less'):  # Skip if there's no CUI assigned for the abbr
                continue
            if (not use_header_abbr) and e <= first_lb:  # Skip if we don't want to use abbrs in the header
                continue

            if label[0] in cui_labels_dict:
                cui_labels_dict[label[0]].append(label[1])
            else:
                cui_labels_dict[label[0]] = [label[1]]

            abbr, left, right = text[s:e], text[:s], text[e:-1]
            abbr, left, right = abbr.strip(), left.strip(), right.strip()
            left = trim_context(left, True)
            right = trim_context(right, False)
            cui = label[0]
            examples.append((abbr, left, right, cui))
            anno_cnt_temp += 1
        print(f'\t{fname}: {anno_cnt_temp}')
    return examples, cui_labels_dict

# %%
train_examples, train_cui_labels_dict = get_examples_and_cui_labels(train_note_dir, train_anno_dir, training=True)
print(f'{len(train_examples)} training examples found')
# 	25950-160092-RADIOLOGY_REPORT.pipe.txt: 15
# 	26136-101545-ECHO_REPORT.pipe.txt: 5
# 	26176-226973-RADIOLOGY_REPORT.pipe.txt: 11
# 	26563-387055-RADIOLOGY_REPORT.pipe.txt: 14
# 3805 training examples found

# %%
# Print some training data
print(train_examples[0], end='\n\n')
print(train_examples[10], end='\n\n')
print(train_examples[200], end='\n\n')
print(train_examples[3000], end='\n\n')
print(train_examples[-1])
# Out:
# ('F', '16139 | 98 | 15836 | DISCHARGE_SUMMARY | 2015-03-24 00:00:00.0 | | | | Admission Date: [**2015-03-17**] Discharge Date: [**2015-03-24**] Date of Birth: [**1974-10-03**] Sex:', 'Service: Neurosurgery HISTORY OF PRESENT ILLNESS: The patient is a 40-year-old female with complaints of headache and dizziness. In [**2015-01-14**], the patient had headache with neck stiffness and was unable to walk for 45 minutes. The patient also had a similar episode a year and a half ago where she had inability to walk without pain. She had a headache at that time which was relieved with Tylenol. PAST MEDICAL HISTORY: Hypothyroidism. ALLERGIES: Penicillin and Bactrim which causes a rash. MEDICATIONS: Levoxyl 1.75 mg. PHYSICAL EXAMINATION: On physical examination, her blood pressure was 104/73, pulse 79. In general, she was a woman in no acute distress. HEENT: Nonicteric. Pupils are equal, round, and reactive to light. Extraocular movements are full. Pharynx is benign. Tongue midline. Neck is supple.', 'C0015780')
#
# ('EOMs', 'was awake, alert. Pupils are equal, round, and reactive to light. EOMs are full. No facial droop, no drift. Strength down the legs was [**05-18**]. On postoperative day #1, the patient was taken to arteriogram, where she underwent a cerebral angiogram to evaluate clipping of the aneurysm. It was found at that time that the patient had a third aneurysm and that the MCA aneurysm which was clipped was at the origin of the anterior temporal artery and not the one at the MCA bifurcation. The patient was therefore taken back to the operating room for a clipping of the second MCA aneurysm without intraoperative complication. The patient was monitored in the Surgical Intensive Care Unit. She was alert, awake, oriented, complaining of severe headache, moving all extremities.', 'full, negative drift, a smile was symmetric, IP is [**05-18**]. The patient was then discharged to the floor on [**2015-03-20**]. She has been out of bed and ambulating with Physical Therapy, tolerating a regular diet, and voiding spontaneously. She has been seen by Physical Therapy, and was found to be safe to discharge to home with home physical therapy on [**2015-03-24**]. Her incision is clean, dry, and intact and she is neurologically stable. DISCHARGE MEDICATIONS: 1. Hydromorphone 2-6 mg po q4h prn. 2. Synthroid 175 mcg po q day. 3. Colace 100 mg po bid. CONDITION ON DISCHARGE: Stable. FOLLOW-UP INSTRUCTIONS: She will follow up in 10 days for staple removal with Dr. [**Last Name (STitle) 570**]. [**Location (un) 571**] [**Initials (NamePattern4) **] [**Last Name (NamePattern4) **], M.D.', 'C0149566')
#
# ('MUST', 'Epi-0-2 Micro: [**2017-11-29**] BLOOD CULTURE EMERGENCY [**Hospital1 **] Pending [**2017-11-28**] BLOOD CULTURE EMERGENCY [**Hospital1 **] Pending [**2017-11-28**] URINE EMERGENCY [**Hospital1 **] Pending ECG: 100bpm, nl axis, nl intervals, no st-tw changes. CXR: 1. Suboptimal positioning of central venous catheter within the mid-right at
# %%
test_examples, test_cui_labels_dict = get_examples_and_cui_labels(test_note_dir, test_anno_dir, training=False)
print(f'{len(test_examples)} test examples found')
# Out:
# ../data/sc13t2/Task2ReferenceStd_CLEFShARe2013Test_StrictAndLenientpipe -> 99 annotation files found
# 	00176-102920-ECHO_REPORT.pipe.txt: 9
# 	00381-006281-DISCHARGE_SUMMARY.pipe.txt: 31
# 	00534-017453-DISCHARGE_SUMMARY.pipe.txt: 1
# 	00534-100076-ECHO_REPORT.pipe.txt: 9
# 	01160-000945-DISCHARGE_SUMMARY.pipe.txt: 7
# 	01163-001840-DISCHARGE_SUMMARY.pipe.txt: 115
# 	01222-104065-ECHO_REPORT.pipe.txt: 7
# 	02740-024700-DISCHARGE_SUMMARY.pipe.txt: 8
# 	03087-026480-DISCHARGE_SUMMARY.pipe.txt: 26
# 	03298-014440-DISCHARGE_SUMMARY.pipe.txt: 9
# 	03628-023268-DISCHARGE_SUMMARY.pipe.txt: 10
# 	03835-028462-DISCHARGE_SUMMARY.pipe.txt: 9
# 	04082-167766-RADIOLOGY_REPORT.pipe.txt: 18
# 	04525-003099-DISCHARGE_SUMMARY.pipe.txt: 114
# 	04882-004677-DISCHARGE_SUMMARY.pipe.txt: 68
# 	04995-028156-DISCHARGE_SUMMARY.pipe.txt: 37
# 	05065-011493-DISCHARGE_SUMMARY.pipe.txt: 112
# 	05163-019624-DISCHARGE_SUMMARY.pipe.txt: 3
# 	05382-010331-DISCHARGE_SUMMARY.pipe.txt: 124
# 	05837-000274-DISCHARGE_SUMMARY.pipe.txt: 14
# 	06134-005003-DISCHARGE_SUMMARY.pipe.txt: 132
# 	06557-009968-DISCHARGE_SUMMARY.pipe.txt: 62
# 	07214-025053-DISCHARGE_SUMMARY.pipe.txt: 13
# 	07546-000040-DISCHARGE_SUMMARY.pipe.txt: 7
# 	07683-016743-DISCHARGE_SUMMARY.pipe.txt: 11
# 	07797-005646-DISCHARGE_SUMMARY.pipe.txt: 54
# 	08216-388895-RADIOLOGY_REPORT.pipe.txt: 14
# 	08324-097667-ECHO_REPORT.pipe.txt: 24
# 	08415-016301-DISCHARGE_SUMMARY.pipe.txt: 26
# 	08786-003318-DISCHARGE_SUMMARY.pipe.txt: 81
# 	08990-002227-DISCHARGE_SUMMARY.pipe.txt: 35
# 	09248-026497-DISCHARGE_SUMMARY.pipe.txt: 141
# 	09339-028983-DISCHARGE_SUMMARY.pipe.txt: 14
# 	09531-108127-ECHO_REPORT.pipe.txt: 7
# 	09602-000963-DISCHARGE_SUMMARY.pipe.txt: 8
# 	09703-109051-ECHO_REPORT.pipe.txt: 26
# 	10434-169426-RADIOLOGY_REPORT.pipe.txt: 9
# 	10539-022213-DISCHARGE_SUMMARY.pipe.txt: 98
# 	10689-110055-ECHO_REPORT.pipe.txt: 8
# 	10773-027033-DISCHARGE_SUMMARY.pipe.txt: 19
# 	21115-101632-ECHO_REPORT.pipe.txt: 27
# 	21312-018707-DISCHARGE_SUMMARY.pipe.txt: 14
# 	21815-002962-DISCHARGE_SUMMARY.pipe.txt: 16
# 	21951-203738-RADIOLOGY_REPORT.pipe.txt: 18
# 	21979-010316-DISCHARGE_SUMMARY.pipe.txt: 43
# 	22159-004946-DISCHARGE_SUMMARY.pipe.txt: 110
# 	22788-021533-DISCHARGE_SUMMARY.pipe.txt: 24
# 	24307-009748-DISCHARGE_SUMMARY.pipe.txt: 17
# 	24435-000622-DISCHARGE_SUMMARY.pipe.txt: 11
# 	24786-014472-DISCHARGE_SUMMARY.pipe.txt: 8
# 	25150-027400-DISCHARGE_SUMMARY.pipe.txt: 42
# 	25775-007416-DISCHARGE_SUMMARY.pipe.txt: 144
# 	26522-011368-DISCHARGE_SUMMARY.pipe.txt: 68
# 3774 test examples found

# %%
# Print some test data
print(test_examples[0], end='\n\n')
print(test_examples[10], end='\n\n')
print(test_examples[200], end='\n\n')
print(test_examples[3000], end='\n\n')
print(test_examples[-1])
# Out:
# ('ECHO', '102920 | 176 | 2167 |', '_REPORT | 2013-09-23 00:00:00.0 | | PATIENT/TEST INFORMATION: Indication: Pericardial effusion. Height: (in) 68 Weight (lb): 184 BSA (m2): 1.97 m2 BP (mm Hg): 140/80 HR (bpm): 70 Status: Inpatient Date/Time: [**2013-09-23**] at 10:20 Test: TTE (Focused views) Doppler: No doppler Contrast: None Technical Quality: Adequate | | INTERPRETATION: Findings: LEFT ATRIUM: The left atrium is moderately dilated. The left atrium is elongated. RIGHT ATRIUM/INTERATRIAL SEPTUM: The right atrium is moderately dilated. LEFT VENTRICLE: There is severe symmetric left ventricular hypertrophy. The left ventricular cavity size is normal. Overall left ventricular systolic function is low normal (LVEF 50-55%). LV WALL MOTION: The following resting regional left ventricular wall motion abnormalities are seen: basal inferoseptal - hypokinetic; mid inferoseptal - hypokinetic; basal inferior - hypokinetic; mid inferior - hypokinetic;', 'C0013516')
#
# ('GI', '6281 | 381 | 17672 | DISCHARGE_SUMMARY | 2018-05-22 00:00:00.0 | | | | Admission Date: [**2018-05-16**] Discharge Date: [**2018-05-22**] Date of Birth: [**1973-02-21**] Sex: F Service: SURGERY Allergies: Penicillins / Flagyl Attending:[**Attending Info 311**] Chief Complaint: Abdominal pain/abcess Major Surgical or Invasive Procedure: Ultrasound guided abdominal drain [**2018-05-17**] History of Present Illness: 44 yo female transfer here from [**Hospital 369**] complaining of mid abdominal pain and redness. Over the last 2 weeks, she noticed night sweats and subjective fever at home. She was transfered to [**Hospital1 27**] per recommendation of her', 'specialist Dr. [**Last Name (STitle) 5060**]. The CT showed mainly anechoic (cystic) collection in the deep subcutaneous tissues of the lower midline abdominal wall, which measures up to 3.4 cm sagittal x 3 cm AP x 3.8 cm transverse. Some heterogenous hyperechoic material is noted within this mainly cystic collectionan abdominal abcess was noted. Past Medical History: Crohns s/p 17 surgeries Ileostomy 1993; Left abdominal stoma ventral Hernia repain x 2 peripheral neuropathy anxiety depression Social History: Disabled No ETOh, no smoking (quit 3 months ago; 30 pack year history) Family History: non-contributory Physical Exam: VS: 97.8, 88, 104/70, 20 Gen: NAD Head: no oral lesions Chest: CTA bilat. CV: RRR, no M/R/G GI/Abd: 10 cm epigastric mass with mild erythema [**Hospital Unit Name **]: tender to palpation,', 'C0521362')
family History: No significant history of familial heart disease. Paternal Grandmother had', 'at age 78. Physical Exam: VITALS: T Afebrile HR 55 BP 118/78 RR 15 Sat 98 GENERAL: well developed male in NAD SKIN: no rashes HEAD: NC/AT EYES: EOMI, Anicteric, R pupil located laterally on [**Female First Name (un) 3650**], L pupil dyssymetric THROAT: No erythema, no tonsillar enlargement, tongue midline NECK: No stiffness, No masses, No LAD, Palpable carotid pulses, no bruits, no JVD CHEST: no supraclavicular or axillary LAD, Lungs Clear to Asculation, No Wheezes/Rhonchi/Crackles HEART: normal PMI, RRR, No Murmurs/Gallops/Rubs BACK: No CVA Tenderness, No spinal tenderness ABDOMEN: Flat, NABS, Soft, No organomegaly, No masses, No guarding, No rebound EXT: No clubbing/cyanosis/edema. Good Pulses. NEURO: oriented to person, place, time Pertinent Results: Admission Labs: [**2012-09-09**] 07:25PM WBC-16.5* RBC-4.35* HGB-14.2 HCT-40.8 MCV-94 MCH-32.7* MCHC-34.8 RDW-12.6 [**2012-09-09**]', 'C0027051')
#
# ('ICH', "1000mg (for approx 50kg female) slowly, to prevent risk of dropping BP further and cardiac arrhythmia, then started 100mg q8h. Monitored lytes, coags, cbc, cardiac enzymes. Addressed code status and goals of care via further family discussions. Met with family husband and daughter evening @11:50pm [**12-28**] and patient's code status was made Comfort Measures Only. Confirmed with NeuroICU attending Dr. [**First Name8 (NamePattern2) **] [**Name (STitle) **] and ICU resident Dr. [**First Name4 (NamePattern1) **] [**Last Name (NamePattern1) **]. Patient was subsequently extubated and passed away overnight from respiratory failure. Family was notified and declined autopsy. Medications on Admission: lasix 20 mg bid lipitor 40 mg qd diovan 160 mg qd labetalol 200 mg bid asa 81 mg carbamazepine 100mg bid Discharge Medications: Discharge Disposition: Expired Discharge Diagnosis:", 'Discharge Condition: Expired [**First Name8 (NamePattern2) **] [**Name8 (MD) **] MD [**MD Number 511**] Completed by: [**Name6 (MD) 512**] CHU MD [**MD Number 513**] [**2018-03-23**] @ 1548 Signed electronically by: DR. [**First Name8 (NamePattern2) **] [**Name (STitle) **] on: FRI [**2018-04-06**] 4:39 PM (End of Report)', 'C2937358')

# %% [markdown]
# ## Abbreviation Normalization

# %%
# Get some statistics of training abbrs
abbr_var_set = set(list(zip(*train_examples))[0])
print(f'{len(abbr_var_set)} training abbr variations\n')
print(sorted(abbr_var_set))
# Out:
# 843 training abbr variations
#
# ['+EtOH', '02', '02 sat', '16Fr', '18Fr', '2D', '2u', '3VD', '3vd', '5', '5u', 'A', 'A&Ox3', 'A+O times 3', 'A-GRAM', 'A-V', 'A-comm', 'A. fib', 'A/O x3', 'A/P', 'AAA', 'AAO', 'AAO x3', 'AAOx3', 'ABD', 'ABD/PEL', 'ABG', 'AC', 'ACE', 'ACLS', 'ACOVE', 'ADAT', "ADD'L", 'ADLs', 'AFB', 'AFIB', 'AFib', 'AH', 'AHA', 'AI', 'AICD', 'AML', 'AMLs', 'ANGIO', 'AO', 'AOx3', 'AP', 'APC', 'AR', 'ARDS', 'AS', 'ASA', 'ASCTES', 'ASD', 'AT', 'ATN', 'AV', 'AVF', 'AVN', 'AVR', 'Abd', 'Abd U/S', 'Abxs', 'Ag', 'Amt', 'Angio', 'AoVA', 'B', 'B/L', 'B12', 'BAL', 'BCXR', 'BID', 'BIPAP', 'BL', 'BM', 'BP', 'BPH', 'BPs', 'BRAT', 'BRBPR', 'BS', 'BSA', 'BUN', 'BiPAP', 'Bili', 'Bp', 'Bs', 'C', 'C-SPINE', 'C-Spine', 'C-section', 'C-spine CT', 'C. Diff', 'C/D/I', 'C/o', 'C2', 'C3', 'CA', 'CABG', 'CAD', 'CAP', 'CARD', 'CAT', 'CATH', 'CCA', 'CCU', 'CCY', 'CD', 'CD4', 'CE', 'CEA', 'CECT', 'CFA', 'CFV', 'CHF', 'CHI', 'CIWA', 'CKs', 'CMO', 'CN', 'COPD', 'CP', 'CPAP', 'CPB', 'CPP', 'CPT', 'CRP', 'CSF', 'CSRU', 'CSU', 'CT', 'CT ABD W&W/O C', 'CT C-SPINE W/O CONTRAST', 'CT PELVIS W&W/O C', 'CTA', 'CTAB', 'CTs', 'CV', 'CVA', 'CVD', 'CVL', 'CVl', 'CXR', 'Ca', 'Card', 'Cath', 'Cdiff', 'Ceftaz', 'Clinda', "Con't", 'Cont', 'Cspine', 'Cx', 'CxR', 'D', "D/C'd", 'D/O', 'D1', 'D50', 'DART', 'DC', 'DDX', 'DF', 'DFA', 'DM', 'DM2', 'DNI', 'DNR', 'DP', 'DT', 'DTs', 'DVT', 'Ddx', 'Disp', 'E', 'ECA', 'ECG', 'ECHO', 'ECMO', 'ECT', 'EDV', 'EEG', 'EF', 'EGD', 'EIA', 'EKG', 'EMS', 'EMTs', 'EOMI', 'EOMs', 'ER', 'ERCP', 'ESLD', 'ESR', 'ESRD', 'ETOH', 'ETT', 'ETT MIBI', 'EVAL', 'EVD', 'EX LAP', 'EXAM', 'EXT', 'EXTREM', 'Echo', 'EtOH', 'EtOHism', 'EtOh', 'EtoH', 'Exam', 'Ext', 'Extrem', 'F', 'F/U', 'FEN', 'FENa', 'FFP', 'FH', 'FI02', 'FICU', 'FIO2', 'FLUOR', 'FLUORO', 'FNA', 'FNF', 'FR', 'FROM', 'FVC', 'Fr', 'G', 'G- J', 'G-J', 'GCS', 'GDC', 'GEN', 'GERD', 'GI', 'GIB', 'GRE', 'GSW', 'GTT', 'GUID', 'Gen', 'Gent', 'H/o', 'HA', 'HAART', 'HASTE', 'HCFA', 'HCT', 'HD', 'HD#2', 'HD2', 'HDL', 'HEENT', 'HIT', 'HIV', 'HIV+', 'HO', 'HOCM', 'HOP', 'HPI', 'HR', 'HSM', 'HTN', 'Hapto', 'HbA1c', 'Hct', 'Heent', 'Heme', 'Hep B', 'Htn', 'Hx', 'I', 'I/O', 'I/P', 'IABP', 'ICA', 'ICA/CCA', 'ICD', 'ICU', 'ID', 'II', 'III', 'IJ', 'IM', 'INR', 'IOUS', 'IP', 'IR', 'IT', 'IV', 'IVC', 'IVF', 'IX', 'Ig', 'Intra-op', 'J', 'J-tube', 'JP', 'JVD', 'JVP', 'K', 'KUB', 'L', 'L1', 'L3', 'L4', 'L5', 'L>R', 'LA', 'LAA', 'LAB', 'LAD', 'LAT', 'LBP', 'LCA', 'LCX', 'LDH', 'LDL', 'LE', 'LENIs', 'LEs', "LFT's", 'LFTs', 'LGI', 'LGIB', 'LH', 'LIMA', 'LLE', 'LLL', 'LM', 'LMCA', 'LMP', 'LN', 'LO', 'LOC', 'LOWER', 'LOWER EXT', 'LP', 'LT', 'LUE', 'LUL', 'LV', 'LVEF', 'LVH', 'LVOT', 'LegExt', 'Legflex', 'M', 'MAE', 'MAP', 'MCA', 'MDCT', 'MDI', 'MI', 'MIBG', 'MIBI', 'MM', 'MMM', 'MR', 'MRA', 'MRI', 'MRSA', 'MS', 'MUST', 'MV', 'MVA', 'MVC', 'MVI', 'MVP', 'Mg', 'N', 'NA', 'NABS', 'NAD', 'NC', 'NCHCT', 'NCSLC', 'ND', 'NEBH', 'NEG', 'NEURO', 'NG', 'NGT', 'NIDDM', 'NIHSS', 'NPH', 'NPO', 'NRB', 'NS', 'NSAID', 'NSCLC', 'NSG', 'NSU', 'NSVT', 'NT', 'Neuro', 'Nl', 'Nt', 'O2', 'O2 sat', 'O2 sats', 'OD', "OD'd", 'OGT', 'OM', 'OMFS', 'OP', 'OR', 'ORIF', 'OSA', 'OSH', 'OT', 'P', 'PA', 'PACU', 'PAP', 'PCA', 'PCN', 'PCN G', 'PCP', 'PDA', 'PE', 'PEA', 'PEEP', 'PEG', 'PEL', 'PERC G/G-J TUBE PLMT', 'PERLA', 'PERRL', 'PERRLA', 'PET', 'PET CT', 'PEUMONIA', 'PF', 'PFO', 'PICA', 'PICC', 'PLB', 'PLCT', 'PM', 'PMH', 'PMHx', 'PMI', 'PNA', 'PO', "PO's", 'POD', 'POD#1', 'POD#3', 'POD1', 'POD2', 'POD3', 'POD4', 'POD6', 'PORT', 'PP', 'PPD', 'PPI', 'PPN', 'PR', 'PRBC', 'PRBCs', 'PRE-OP', 'PREOP', 'PRN', 'PS', 'PSA', 'PSH', 'PT', 'PT/INR', 'PTA', 'PTC', 'PTCA', 'PTH', 'PTT', 'PTX', 'PUD', 'PVD', 'Pen G', 'Plts', 'Post-op', 'Postop', 'Preop', 'Proph', 'Pt', 'Pulm', 'Pulse', 'Q4H', 'QHS', 'QID', 'QOD', 'R', 'R AKA', 'R BKA', 'R Tib/FIb XR', 'R-N-Y', 'R/L', 'R/O', 'RA', 'RAP', 'RBBB', 'RBC', 'RCA', 'REPLCT', 'RIJ cvl', 'RISS', 'RLE', 'RLQ', 'ROM', 'ROS', 'RR', 'RRR', 'RUE', 'RUL', 'RUQ', 'RV', 'RVAD', 'Resp', 'Retic', 'Rx', 'S', 'S/P', 'S1', 'S2', 'S3', 'S4', 'SAH', 'SBP', 'SC' ...

# %%
# Get some statistics of test abbrs
abbr_var_set = Counter(list(zip(*test_examples))[0])
print(f'{len(abbr_var_set)} test abbr variations\n')
print(sorted(abbr_var_set))
# Out:
# 871 test abbr variations
#
# ['02', '02 sat', '2', '2D', '3U', '3VD', '5V', '5VCABG', '60Amp', '6MP', 'A', 'A and Ox3', 'A fib', 'A&O X 3', 'A&Ox2', 'A&Ox3', 'A+O x 3', 'A-Fib', 'A-V', 'A/O x3', 'A/P', 'AA', 'AAA', 'AAOx3', 'ABD', 'ABG', 'AC', 'ACE', 'ACEI', 'ACLS', 'ACS', 'AD', 'ADF', 'ADL', 'ADLs', 'AF', 'AFB', 'AFIB', 'AFib', 'AI', 'AICD', 'AIDS', 'ALT', 'AMA', 'ANC', 'AO', 'AO x 3', 'AOCD', 'AP', 'APD', 'APF', 'AR', 'ARDS', 'ARF', 'AS', 'ASA', 'ASD', 'AST', 'AT', 'ATNC', 'AV', 'AV-block', 'AVG', 'AVR', 'Ab', 'Abd', 'Abx', 'Afib', 'Agap', 'Alc', 'B', 'B-blockers', 'B/L', 'B12', 'BB', 'BG', 'BGs', 'BIBA', 'BID', 'BIPAP', 'BKA', 'BL', 'BLE', 'BNP', 'BODMC', 'BP', 'BPH', 'BRBPR', 'BS', 'BSA', 'BSO', 'BUN', 'Barb', 'Bicarb', 'Bilat', 'C', 'C-SPINE', 'C-spine', 'C2', 'C3-4', 'C4-5', 'C5-6', 'C6-7', 'CA', 'CABG', 'CAD', 'CATH', 'CBC', 'CC', 'CCE', 'CCU', 'CCY', 'CDDP', 'CE', 'CEA', 'CENT', 'CHB', 'CHF', 'CI', 'CICU', 'CK', 'CKD', 'CKMB', 'CKs', 'CME', 'CMO', 'CMV', 'CN', 'CNS', 'CO', 'CO2', 'COMM', 'COP', 'COPD', 'CP', 'CPAP', 'CPB', 'CPK', 'CPT', 'CRI', 'CRP', 'CSRU', 'CSU', 'CT', 'CT angio', 'CTA', 'CTA B', 'CTA-B', 'CTAB', 'CV', 'CVA', 'CVP', 'CVS', 'CVVH', 'CX', 'CXR', 'CXRs', 'Card', 'Cardio', 'Cath', 'Comm', 'Cont', 'Cor', 'Cr', 'Cre', 'Creat', 'Ct', 'Cx', 'D', "D/C'd", 'D/c', 'D1', 'D50', 'DC meds', "DC'D", 'DES', 'DISPO', 'DM', 'DM 2', 'DM2', 'DMII', 'DNI', 'DNR', 'DOA', 'DOE', 'DP', 'DPs', 'DS', 'DSF', 'DTRS', 'DTRs', 'DVT', 'DVTs', 'Dec', 'Derm', 'Dispo', 'E', 'E.D', 'E.D.', 'E/e', 'EBL', 'ECG', 'ECHO', 'EEG', 'EF', 'EGD', 'EKG', 'EKGs', 'EMS', 'EMT', 'EOM', 'EOM exam', 'EOMI', 'EOMS', 'EOMi', 'EP', 'ESBL', 'ESR', 'ESRD', 'ET', 'ETOH', 'ETOh', 'ETT', 'EXT', 'EXTR', 'EXTREM', 'Echo', 'Epi', 'EtOH', 'Eval', 'Exam', 'Ext', 'Extr', 'Extrem', 'F', 'F/E', 'F/U', 'FBS', 'FEN', 'FFR', 'FH', 'FHL', 'FICU', 'FIO2', 'FK506', 'FLUOR', 'FLUORO', 'FM', 'FROM', 'FSBG', 'FX', 'Fem', 'FiO2', 'Fio2', 'G', 'GB', 'GCS', 'GE', 'GEN', 'GERD', 'GI', 'GIB', 'GUID', 'Gen', 'H', 'H/ pyloru', 'H/o', 'HA', 'HCP', 'HCT', 'HCTZ', 'HCV', 'HCV Ab', 'HD', 'HEENT', 'HENNT', 'HF', 'HH', 'HIT', 'HOB', 'HPI', 'HR', 'HS', 'HSM', 'HSV', 'HTN', 'Hct', 'Hctz', 'Heent', 'Heme', 'Hep C', 'HepC', 'Hosp', 'Ht', 'Hx', 'I', 'I&D', 'IABP', 'ICA', 'ICD', 'ICH', 'ICU', 'ID', 'IGA', 'IGF-1', 'IGF-2', 'IGGA', 'II', 'III', 'IJ', 'IMI', 'INH', 'INR', 'IV', 'IVC', 'IVDA', 'IVDU', 'IVF', 'IVFs', 'IVP', 'IVs', 'IX', 'IgA', 'Irreg', 'Is', 'J-P', 'JP', 'JVD', 'JVP', 'K', 'KUB', 'L', 'L DP', 'L MCA', 'L-R', 'L2', 'LA', 'LAD', 'LAR', 'LAT', 'LBBB', 'LCX', 'LDH', 'LDL', 'LE', "LE's", 'LFT', 'LFTs', 'LGH', 'LIMA', 'LLL', 'LLQ', 'LLSB', 'LM', 'LMCA', 'LP', 'LPL', 'LUSB', 'LV', 'LVEDP', 'LVEF', 'LVH', 'LVOT', 'Lab', 'Labs', 'Lat', 'M', 'MAE', 'MAP', 'MB', 'MCA', 'MCV', 'MI', 'MIBI', 'MID', 'MM', 'MMM', 'MMP', 'MMW', 'MOYB', 'MR', 'MRA', 'MRG', 'MRI', 'MRSA', 'MRV', 'MS', 'MSSA', 'MVH', 'MVO2', 'MVP', 'MVR', 'Musc', 'N', 'N-G', 'N/C', 'NA', 'NABS', 'NAD', 'NC', 'NCAT', 'NCHCT', 'ND', 'NET', 'NEURO', 'NG', 'NGT', 'NGTD', 'NH', 'NIDDM', 'NKDA', 'NL', 'NOS', 'NPH', 'NPO', 'NR', 'NRB', 'NS', 'NSCLC', 'NSR', 'NSRs', 'NSTEMI', 'NSVT', 'NT', 'NTG', 'Na', 'Neck', 'Neo', 'Neuro', 'NeuroICU', 'Nml', 'O2', 'O2 sat', 'O2 sats', 'O2Sat', 'O2sat', 'OA', 'OB', 'OCR', 'OG', 'OGT', 'OM', 'OM-1', 'OM-2', 'OM1', 'OM2', 'OMS', 'OOB', 'OP', 'OR', 'ORIF', 'ORL', 'OS', 'OSA', 'OSH', 'OT', 'Onc', 'Os', 'P', 'P02', 'PA', 'PACU', 'PAD', 'PAF', 'PAfib', 'PCA', 'PCAs', 'PCI', 'PCIs', 'PCP', 'PCW', 'PCWP', 'PCXR', 'PDA', 'PE', 'PEA', 'PEG', 'PERRL', 'PERRLA', 'PET', 'PFO', 'PGM', 'PICC', 'PL', 'PLCT', 'PM', 'PMH', 'PMHx', 'PMI', 'PMN', 'PMNs', 'PNA', 'PND', 'PO', 'PO2', 'POD', 'POs', 'PPI', 'PPX', 'PPx', 'PR', 'PRBC', "PRBC's", 'PRBCs', 'PRELIM', 'PS', 'PSA', 'PSV', 'PT', 'PTA', 'PTCA', 'PTH', 'PTHrP', 'PTSD', 'PTs', 'PULM', 'PVCs', 'PVD', 'PaO2', 'Peep', 'Perrla', 'Pt', "Pt's", 'Pts', 'Pulm', 'R', 'R DP', 'R ICA', 'R IJ', 'R/O', 'R>L', 'RA', 'RAMs', 'RAP', 'RBB', 'RBBB', 'RC', 'RCA', 'RCHOP', 'RCIA', 'REMOVE', 'REPLCT', 'RESP', 'RFA', 'RHF' ...

# %%
# Get special symbols
special_symbols = set()
for abbr in list(zip(*train_examples))[0] + list(zip(*test_examples))[0]:
    for c in abbr:
        if not c.isalnum():
            special_symbols.add(c)
special_symbols
# Out:
# {' ', '#', '&', "'", '+', '-', '.', '/', '>'}

# %%
# regex_sym = re.compile('(\+/-)|[-_\.]')
# regex_sym = re.compile('(\+/-)|[-_\.\\+]')
regex_sym = re.compile('[-_\.\\+/&#> \']')
# regex_sym = re.compile('[-_\.\+/&#> \']')
# regex_sym = re.compile('[-_\.\\+/&#> \'\(\)\[\]\:\%\!\,\*]')
def normalize_abbr_variation(abbr):
    abbr = abbr.strip()
    abbr = regex_sym.sub('', abbr)
    abbr = abbr.lower()
    return abbr

abbr_set = set(list(zip(*train_examples))[0])
# abbr_set = set(list(zip(*test_examples))[0])
abbr_group_dict = {}
group_abbr_dict = {}
for abbr in abbr_set:
    abbr_norm = normalize_abbr_variation(abbr)
    if abbr_norm in abbr_group_dict:
        abbr_group_dict[abbr_norm].append(abbr)
    else:
        abbr_group_dict[abbr_norm] = [abbr]
    group_abbr_dict[abbr] = abbr_norm
        
print(f'{len(abbr_set)} abbrs -> {len(abbr_group_dict)} abbr groups\n')

for abbr_group in sorted(abbr_group_dict.keys()):
    print(f"{abbr_group:15}: {', '.join(['[%s]'%abbr for abbr in abbr_group_dict[abbr_group]])}")
# Out:
# 843 abbrs -> 670 abbr groups
#
# 02             : [02]
# 02sat          : [02 sat]
# 16fr           : [16Fr]
# 18fr           : [18Fr]
# 2d             : [2D]
# 2u             : [2u]
# 3vd            : [3vd], [3VD]
# 5              : [5]
# 5u             : [5u]
# a              : [A]
# aaa            : [AAA]
# aao            : [AAO]
# aaox3          : [AAOx3], [AAO x3]
# abd            : [Abd], [ABD], [abd]
# abdpel         : [ABD/PEL]
# abdus          : [Abd U/S]
# abg            : [ABG]
# abx            : [abx]
# abxs           : [Abxs]
# ac             : [AC]
# ace            : [ACE]
# acls           : [ACLS]
# acomm          : [A-comm]
# acove          : [ACOVE]
# adat           : [ADAT]
# addl           : [ADD'L]
# adls           : [ADLs]
# afb            : [AFB]
# afib           : [AFib], [AFIB], [afib], [A. fib]
# ag             : [Ag]
# agram          : [A-GRAM]
# ah             : [AH]
# aha            : [AHA]
# ai             : [AI]
# aicd           : [aicd], [AICD]
# alkphos        : [alk phos]
# aml            : [AML]
# amls           : [AMLs]
# amt            : [Amt]
# angio          : [ANGIO], [Angio]
# ao             : [AO]
# aotimes3       : [A+O times 3]
# aova           : [AoVA]
# aox3           : [AOx3], [A/O x3], [A&Ox3]
# ap             : [AP], [A/P]
# apc            : [APC]
# ar             : [AR]
# ards           : [ARDS]
# as             : [AS]
# asa            : [ASA]
# asctes         : [ASCTES]
# asd            : [ASD]
# asp            : [asp]
# assoc          : [assoc]
# at             : [AT]
# atn            : [ATN]
# av             : [AV], [A-V]
# avf            : [AVF]
# avn            : [AVN]
# avr            : [AVR], [avr]
# azithro        : [azithro]
# b              : [B]
# b12            : [B12]
# bal            : [BAL]
# bcxr           : [BCXR]
# bid            : [b.i.d], [bid], [BID]
# bilat          : [bilat]
# bili           : [Bili]
# bipap          : [BIPAP], [BiPAP]
# biv            : [biv]
# bl             : [b/l], [B/L], [BL]
# bm             : [BM]
# bp             : [BP], [Bp], [bp]
# bph            : [BPH]
# bps            : [BPs]
# brat           : [BRAT]
# brbpr          : [BRBPR]
# bs             : [Bs], [bs], [BS]
# bsa            : [BSA]
# bun            : [BUN]
# c              : [c], [C]
# c2             : [C2]
# c3             : [C3]
# ca             : [CA], [ca], [Ca]
# cabg           : [CABG], [cabg]
# cad            : [CAD]
# cap            : [CAP]
# card           : [Card], [CARD]
# cardiapulm     : [cardiapulm]
# cat            : [CAT]
# cath           : [CATH], [Cath], [cath]
# cathlab        : [cath lab]
# cca            : [CCA]
# ccu            : [CCU]
# ccy            : [ccy], [CCY]
# cd             : [CD]
# cd4            : [CD4]
# cdi            : [C/D/I]
# cdiff          : [Cdiff], [C. Diff]
# ce             : [CE]
# cea            : [CEA]
# cect           : [CECT]
# ceft           : [ceft]
# ceftaz         : [ceftaz], [Ceftaz]
# cfa            : [CFA]
# cfv            : [CFV]
# chf            : [CHF]
# chi            : [CHI]
# cigs           : [cigs]
# ciwa           : [CIWA]
# cks            : [CKs]
# clinda         : [Clinda]
# cmo            : [CMO]
# cn             : [CN]
# co             : [C/o], [c/o]
# coag           : [coag]
# cont           : [Cont], [cont], [con't], [Con't]
# copd           : [COPD]
# cp             : [CP]
# cpap           : [CPAP]
# cpb            : [CPB]
# cpp            : [CPP]
# cpt            : [CPT]
# crp            : [CRP]
# csection       : [C-section]
# csf            : [CSF]
# cspine         : [C-SPINE], [Cspine], [c-spine], [C-Spine]
# cspinect       : [C-spine CT]
# csru           : [CSRU]
# csu            : [CSU]
# ct             : [CT]
# cta            : [cta], [CTA]
# ctab           : [CTAB]
# ctabdwwoc      : [CT ABD W&W/O C]
# ctcspinewocontrast: [CT C-SPINE W/O CONTRAST]
# ctpelviswwoc   : [CT PELVIS W&W/O C]
# cts            : [CTs]
# cv             : [CV]
# cva            : [CVA], [cva]
# cvd            : [CVD]
# cvl            : [CVL], [CVl]
# cvp            : [cvp]
# cw             : [c/w]
# cx             : [Cx]
# cxr            : [cxr], [CxR], [CXR]
# d              : [d], [D]
# d1             : [D1]
# d50            : [D50]
# dart           : [dart], [DART]
# dc             : [d&C], [DC], [d/c]
# dcd            : [D/C'd], [dc'd], [d/c'd]
# dced           : [d/c'ed]
# ddx            : [Ddx], [DDX]
# df             : [DF]
# dfa            : [DFA]
# diastdysf      : [diast dysf]
# diff           : [diff]
# disp           : [Disp]
# dm             : [DM]
# dm2            : [DM2]
# dni            : [DNI]
# dnr            : [DNR]
# do             : [d/o], [D/O]
# dp             : [DP], [dp]
# dt             : [DT]
# dts            : [DTs]
# dvt            : [DVT]
# dw             : [d/w]
# dxd            : [dx'd]
# e              : [E], [e]
# eca            : [ECA]
# ecg            : [ECG]
# echo           : [echo], [Echo], [ECHO]
# ecmo           : [ECMO]
# ecoli          : [e.coli]
# ect            : [ECT]
# edv            : [EDV]
# eeg            : [EEG]
# ef             : [EF]
# egd            : [EGD], [egd]
# eia            : [EIA]
# ekg            : [EKG]
# ems            : [EMS]
# emts           : [EMTs]
# eomi           : [EOMI], [eomi]
# eoms           : [EOMs]
# epiinject      : [epi inject]
# er             : [ER]
# ercp           : [ERCP]
# esld           : [ESLD]
# esr            : [ESR]
# esrd           : [ESRD]
# etoh           : [+EtOH], [etoh], [ETOH], [EtOH], [EtOh], [EtoH]
# etohism        : [EtOHism]
# ett            : [ETT]
# ettmibi        : [ETT MIBI]
# eval           : [EVAL], [eval]
# evd            : [EVD]
# exam           : [Exam], [exam], [EXAM]
# exlap          : [EX LAP]
# exp            : [exp]
# ext            : [ext], [EXT], [Ext]
# extrem         : [EXTREM], [Extrem]
# f              : [f], [F]
# fem            : [fem]
# fen            : [FEN]
# fena           : [FENa]
# ffp            : [FFP]
# fh             : [FH]
# fi02           : [FI02]
# fib            : [fib]
# ficu           : [FICU]
# fio2           : [FIO2]
# fluc           : [fluc]
# fluor          : [FLUOR]
# fluoro         : [FLUORO], [fluoro]
# fna            : [FNA]
# fnf            : [FNF]
# fr             : [FR], [Fr]
# from           : [FROM]
# fs             : [fs]
# fu             : [f/u], [F/U]
# fvc            : [FVC]
# fx             : [fx]
# fxn            : [fxn]
# g              : [g], [G]
# gcs            : [GCS]
# gdc            : [GDC]
# gen            : [Gen], [GEN]
# gent           : [Gent]
# gerd           : [GERD]
# gi             : [gi], [GI]
# gib            : [GIB]
# gj             : [G- J], [G-J]
# gre            : [GRE]
# gsw            : [GSW], [gsw]
# gtt            : [gtt], [GTT]
# gtube          : [g-tube]
# guid           : [GUID]
# h2o            : [h2o]
# ha             : [HA]
# haart          : [HAART]
# hapto          : [Hapto]
# haste          : [HASTE]
# hba1c          : [HbA1c]
# hcfa           : [HCFA]
# hct            : [Hct], [hct], [HCT]
# hd             : [HD]
# hd2            : [HD#2], [HD2]
# hdl            : [HDL]
# heent          : [HEENT], [Heent]
# heme           : [Heme]
# hepb           : [Hep B]
# hepc           : [hep C]
# hepsc          : [hep sc]
# hit            : [HIT]
# hiv            : [HIV+], [HIV]
# ho             : [h/o], [HO], [H/o]
# hocm           : [HOCM]
# hop            : [HOP]
# hpi            : [HPI]
# hr             : [hr], [HR]
# hsm            : [HSM]
# htn            : [Htn], [HTN]
# hx             : [hx], [Hx]
# hydro          : [hydro]
# hyperchol      : [hyperchol]
# hypo           : [hypo]
# i              : [i], [I]
# iabp           : [IABP]
# ica            : [ICA]
# icacca         : [ICA/CCA]
# icd            : [ICD]
# icu            : [ICU]
# id             : [ID]
# ig             : [Ig]
# ii             : [II]
# iii            : [III]
# ij             : [IJ]
# im             : [IM]
# infxn          : [infxn]
# inr            : [INR]
# inspir         : [inspir]
# intraop        : [Intra-op], [intraop]
# io             : [I/O]
# ious           : [IOUS]
# ip             : [I/P], [IP]
# ir             : [IR]
# irregirreg     : [irreg irreg]
# it             : [IT]
# iv             : [iv], [IV]
# ivc            : [IVC]
# ivf            : [IVF]
# ix             : [IX]
# j              : [J]
# jeje           : [jeje]
# jp             : [JP]
# jtube          : [J-tube]
# jvd            : [JVD]
# jvp            : [JVP]
# k              : [K]
# kub            : [KUB]
# l              : [l], [L]
# l1             : [L1]
# l3             : [L3]
# l4             : [L4]
# l5             : [L5]
# la             : [LA]
# laa            : [LAA]
# lab            : [LAB]
# lac            : [lac]
# lad            : [LAD]
# lat            : [LAT]
# lbp            : [LBP]
# lca            : [LCA]
# lcx            : [LCX]
# ldh            : [LDH]
# ldl            : [LDL]
# le             : [le], [LE]
# legext         : [LegExt]
# legflex        : [Legflex]
# lenis          : [LENIs]
# les            : [LEs]
# levo           : [levo]
# lfts           : [LFT's], [LFTs]
# lg             : [lg]
# lgi            : [LGI]
# lgib           : [LGIB]
# lh             : [LH]
# lima           : [LIMA]
# lle            : [LLE]
# lll            : [LLL]
# lm             : [LM]
# lmca           : [LMCA]
# lmp            : [LMP]
# ln             : [LN]
# lo             : [LO]
# loc            : [LOC]
# lower          : [LOWER]
# lowerext       : [LOWER EXT]
# lp             : [LP]
# lr             : [L>R]
# lt             : [LT]
# lue            : [LUE]
# lul            : [LUL]
# lv             : [LV]
# lvef           : [LVEF]
# lvh            : [LVH]
# lvot           : [LVOT]
# lytes          : [lytes]
# m              : [m], [M]
# mae            : [MAE]
# map            : [MAP]
# mca            : [MCA]
# mdct           : [MDCT]
# mdi            : [MDI]
# me             : [me]
# meds           : [meds]
# met            : [met]
# mg             : [Mg]
# mi             : [MI]
# mibg           : [MIBG]
# mibi           : [MIBI]
# mid            : [mid]
# mm             : [MM]
# mmm            : [MMM], [mmm]
# mr             : [MR]
# mra            : [MRA]
# mri            : [mri], [MRI]
# mrsa           : [MRSA]
# ms             : [MS], [ms]
# must           : [MUST]
# mv             : [MV]
# mva            : [mva], [MVA]
# mvc            : [MVC]
# mvi            : [MVI]
# mvmt           : [mvmt]
# mvp            : [MVP]
# mvt            : [mvt]
# n              : [N], [n]
# na             : [NA], [n/a]
# nabs           : [NABS]
# nad            : [NAD], [nad]
# nc             : [nc], [n/c], [NC]
# nchct          : [NCHCT]
# ncslc          : [NCSLC]
# nd             : [ND], [nd]
# nebh           : [NEBH]
# nebs           : [nebs]
# neg            : [NEG], [neg]
# neuro          : [neuro], [Neuro], [NEURO]
# ng             : [NG], [ng]
# ngt            : [NGT]
# nh             : [nh]
# niddm          : [NIDDM]
# nihss          : [NIHSS]
# nitro          : [nitro]
# nl             : [nl], [Nl]
# nml            : [nml]
# nph            : [NPH]
# npo            : [n.p.o], [NPO]
# nrb            : [NRB]
# ns             : [NS]
# nsaid          : [NSAID]
# nsclc          : [NSCLC]
# nsg            : [NSG]
# nsu            : [NSU]
# nsvt           : [NSVT]
# nt             : [nt], [Nt], [NT]
# o2             : [O2]
# o2sat          : [o2 sat], [O2 sat]
# o2sats         : [O2 sats]
# od             : [od], [OD]
# odd            : [OD'd]
# ogt            : [OGT]
# om             : [OM]
# omfs           : [OMFS]
# op             : [OP], [op]
# optho          : [optho]
# or             : [OR]
# orif           : [ORIF]
# os             : [os]
# osa            : [OSA]
# osh            : [OSH]
# ot             : [OT]
# outpt          : [outpt]
# p              : [p], [P]
# pa             : [PA]
# pacu           : [PACU]
# palp           : [palp]
# pap            : [PAP]
# pca            : [PCA]
# pcn            : [PCN]
# pcng           : [PCN G]
# pco2           : [pCO2]
# pcp            : [PCP]
# pda            : [PDA]
# pe             : [PE]
# pea            : [PEA]
# peep           : [PEEP]
# peg            : [PEG]
# pel            : [PEL]
# pelvis         : [pelvis]
# peng           : [Pen G]
# percggjtubeplmt: [PERC G/G-J TUBE PLMT]
# perla          : [PERLA]
# perrl          : [PERRL]
# perrla         : [PERRLA]
# pet            : [PET]
# petct          : [PET CT]
# peumonia       : [PEUMONIA]
# pf             : [PF]
# pfo            : [PFO]
# pica           : [PICA]
# picc           : [PICC]
# pict           : [pict]
# pkyr           : [pk-yr]
# plb            : [PLB]
# plct           : [PLCT]
# plts           : [Plts]
# pm             : [PM]
# pmh            : [PMH]
# pmhx           : [pmhx], [PMHx]
# pmi            : [PMI]
# pmibi          : [pMIBI]
# pna            : [PNA], [pna]
# po             : [PO], [po], [p.o]
# pod            : [POD]
# pod1           : [POD#1], [POD1]
# pod2           : [POD2]
# pod3           : [POD3], [POD#3]
# pod4           : [POD4]
# pod6           : [POD6]
# port           : [PORT]
# pos            : [PO's]
# postop         : [Post-op], [postop], [post-op], [Postop]
# pp             : [pp], [PP]
# ppd            : [PPD], [ppd]
# ppi            : [PPI]
# ppn            : [PPN]
# pr             : [PR]
# prbc           : [PRBC]
# prbcs          : [PRBCs]
# preop          : [Preop], [pre-op], [PREOP], [PRE-OP]
# prn            : [prn], [PRN]
# proph          : [Proph]
# ps             : [PS]
# psa            : [PSA]
# pscyh          : [pscyh]
# psh            : [PSH]
# pt             : [Pt], [PT], [pt]
# pta            : [PTA]
# ptc            : [PTC]
# ptca           : [PTCA]
# pth            : [PTH]
# ptinr          : [PT/INR]
# pts            : [pts]
# ptt            : [ptt], [PTT]
# ptx            : [ptx], [PTX]
# pud            : [PUD]
# pulm           : [pulm], [Pulm]
# pulse          : [Pulse]
# pvd            : [PVD]
# pw             : [p/w]
# q              : [q], [q.]
# q4h            : [Q4H], [q.4h]
# qam            : [q.a.m], [q.a.m.]
# qd             : [q.d], [qD], [qd]
# qhs            : [QHS], [q.h.s]
# qid            : [q.i.d], [QID]
# qod            : [QOD]
# qpm            : [q.p.m]
# r              : [R], [r]
# ra             : [RA], [ra]
# raka           : [R AKA]
# rap            : [RAP]
# rbbb           : [RBBB]
# rbc            : [RBC]
# rbka           : [R BKA]
# rca            : [RCA]
# recd           : [rec'd]
# redo           : [re-do]
# regurg         : [regurg]
# rehab          : [rehab]
# replct         : [REPLCT]
# resp           : [Resp], [resp]
# retic          : [Retic]
# rijcvl         : [RIJ cvl]
# riss           : [RISS]
# rl             : [R/L]
# rle            : [RLE]
# rlq            : [RLQ]
# rny            : [R-N-Y]
# ro             : [R/O], [r/o]
# rom            : [ROM]
# ros            : [ROS]
# rpda           : [r-PDA]
# rr             : [rr], [RR]
# rrr            : [RRR]
# rsc            : [rsc]
# rt             : [rt]
# rtibfibxr      : [R Tib/FIb XR]
# rue            : [RUE]
# rul            : [RUL]
# ruq            : [RUQ]
# rv             : [RV]
# rvad           : [RVAD]
# rx             : [Rx]
# s              : [S]
# s1             : [S1], [s1]
# s2             : [s2], [S2]
# s3             : [S3]
# s4             : [S4]
# sah            : [SAH]
# sao2           : [SaO2]
# sat            : [Sat]
# sats           : [Sats], [sats]
# sbp            : [SBP]
# sc             : [SC]
# sch            : [SCH]
# scm            : [SCM]
# sda            : [SDA]
# sem            : [SEM]
# sh             : [SH]
# si             : [SI]
# simv           : [SIMV]
# sirs           : [SIRS]
# sma            : [SMA]
# sob            : [SOB], [sob]
# sobx           : [SOBx]
# sochx          : [soc hx]
# sos            : [SOS]
# sp             : [S/P], [s/p], [sp]
# spect          : [SPECT]
# speniclac      : [spenic lac]
# ss             : [s&s]
# sscp           : [SSCP]
# ssi            : [SSI]
# st             : [St]
# stat           : [STAT], [stat]
# stemi          : [STEMI]
# stim           : [stim]
# stir           : [STIR]
# strep          : [strep], [Strep]
# subcu          : [subcu]
# svc            : [SVC]
# svg            : [SVG]
# svo2           : [svo2]
# t              : [t], [T]
# t1             : [T1]
# t12            : [T12]
# t1w            : [T1W]
# t2             : [T2]
# t2w            : [T2W]
# t6             : [T6]
# t8             : [T8]
# t9             : [T9]
# tachy          : [tachy]
# tah            : [TAH]
# tb             : [TB]
# tbna           : [TBNA]
# tc             : [Tc]
# tee            : [TEE]
# tele           : [tele]
# temp           : [temp], [Temp], [TEMP]
# thr            : [THR]
# tia            : [TIA]
# tib            : [tib]
# tid            : [tid]
# timi           : [TIMI]
# timiiii        : [TIMI-III]
# tls            : [TLS]
# tlso           : [TLSO]
# tmax           : [T-max]
# tms            : [TMs]
# tmz            : [TMZ]
# tob            : [tob]
# tof            : [TOF]
# tox            : [Tox]
# tpa            : [tPA], [TPA]
# tpn            : [TPN]
# tr             : [TR]
# trach          : [trach]
# tsh            : [TSH]
# tte            : [TTE]
# ttp            : [TTP]
# turp           : [TURP]
# tx             : [TX]
# ua             : [UA]
# uc             : [UC]
# ucxr           : [UCXR]
# ue             : [UE]
# ues            : [UEs]
# us             : [US], [U.S.], [U/S]
# ush            : [USH]
# uti            : [UTI]
# utis           : [UTIs]
# v              : [v], [V]
# vac            : [VAC]
# vad            : [VAD]
# vanc           : [vanc], [Vanc]
# vanco          : [Vanco], [vanco]
# vas            : [VAS]
# vats           : [VATS]
# vf             : [VF]
# vff            : [VFF]
# vi             : [VI]
# vibe           : [VIBE]
# vicu           : [VICU]
# vii            : [VII]
# viii           : [VIII]
# vitals         : [Vitals]
# vna            : [VNA]
# vre            : [VRE]
# vs             : [Vs], [VS]
# vsd            : [VSD]
# vss            : [VSS]
# w              : [W], [w]
# wbc            : [WBC], [wbc]
# wd             : [WD], [w/d]
# wlmob          : [W/LMOB]
# wn             : [WN]
# wnl            : [wnl]
# wo             : [W/O]
# wwp            : [wwp]
# x              : [X]
# xi             : [XI]
# xii            : [XII]
# xr             : [XR]
# xrt            : [XRT]

# %% [markdown]
# ## Pseudonymization

# %%
texts = []
for d in train_examples + test_examples:
    texts.extend([d[1], d[2]])

# %%
temp_indir = os.path.join(sc13t2_dir, 'temp/')
temp_infpath = os.path.join(temp_indir, 'temp.txt')
temp_outdir = os.path.join(sc13t2_dir, 'temp_pseudonym/')
temp_outfpath = os.path.join(temp_outdir, 'temp.txt')

if not os.path.exists(temp_indir):
    os.makedirs(temp_indir)
with open(temp_infpath, 'w') as fd:
    fd.write('\n'.join(texts))
if os.path.exists(temp_outdir):
    shutil.rmtree(temp_outdir)

# %%
# pip install requests joblib sqlalchemy gensim
# !python mimic-tools/main.py REPLACE \
        --input-dir {temp_indir} \
        --output-dir {temp_outdir} \
        --list-dir mimic-tools/lists
# Out:
# /home/juyongk/.miniconda3/envs/pt/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# 2022-04-19 06:12:07,251 Starting placeholder replacing
# 2022-04-19 06:12:07,251 Loading lists
# 2022-04-19 06:12:07,278 * Postal addresses: 20000 [656C Newport Court Coatesville, PA 19320 ...]
# 2022-04-19 06:12:07,537 * Last names: 88799 [SMITH, JOHNSON, WILLIAMS, JONES, BROWN ...]
# 2022-04-19 06:12:07,541 * Male first names: 1219 [JAMES, JOHN, ROBERT, MICHAEL, WILLIAM ...]
# 2022-04-19 06:12:07,553 * Female first names: 4275 [MARY, PATRICIA, LINDA, BARBARA, ELIZABETH ...]
# 2022-04-19 06:12:07,579 * Phone numbers: 20000 [(666) 372-7835, (923) 739-2644 ...]
# 2022-04-19 06:12:07,605 * Companies: 20000 [Ligula Aenean Gravida Ltd, Non Bibendum Sed LLC ...]
# 2022-04-19 06:12:07,606 * Countries: 264 [Afghanistan, Albania, Algeria, American Samoa ...]
# 2022-04-19 06:12:07,634 * Emails: 20000 [enim.Suspendisse.aliquet@Crasdictum.com, sapien.Cras.dolor@Curabitur.org ...]
# 2022-04-19 06:12:07,634 * Holiday names: 187 [Administrative Professionals Day, Air Force Birthday ...]
# 2022-04-19 06:12:07,641 * Hospital names: 4805 [Southeast Alabama Medical Center, Marshall Medical Center South ...]
# 2022-04-19 06:12:07,668 * Location names: 20000 [Prenzlau, Siegendorf, Hulste ...]
# 2022-04-19 06:12:07,693 * SSN: 20000 [584-80-0392, 121-03-0002, 113-93-0738 ...]
# 2022-04-19 06:12:07,693 * US_States: 50 [Alabama, Alaska, Arizona ...]
# 2022-04-19 06:12:07,694 * Colleges: 450 [Adelphi University, Agnes Scott College, University of Alabama ...]
# 2022-04-19 06:12:07,694 * Wards & Units: 29 [A & E, ICU, Operating Theatre ...]
# 2022-04-19 06:12:07,695 * Websites: 500 [twitpic.com, wsj.com, wikimedia.org ...]
# 2022-04-19 06:12:07,695 * Combining female and male first names: 5494 [MARY, PATRICIA, LINDA ...]
# 2022-04-19 06:12:07,695 Creating mapper
# 2022-04-19 06:12:07,695 Computing number of files to process
# 2022-04-19 06:12:07,696 Replacing placeholders. This can take a long time...
# 2022-04-19 06:12:11,231 Processed: 1/1 (100.0%)
# 2022-04-19 06:12:11,232 Done !
# 2022-04-19 06:12:11,242 Done ! (Time elapsed: 0:00:04)

# %%
with open(temp_outfpath, 'r') as fd:
    texts_pseudo = [l.strip() for l in fd.readlines()]
    
cnt = 0
for i, d in enumerate(train_examples):
    new_d = (d[0], texts_pseudo[cnt], texts_pseudo[cnt+1], d[3])
    train_examples[i] = new_d
    cnt += 2
    
for i, d in enumerate(test_examples):
    new_d = (d[0], texts_pseudo[cnt], texts_pseudo[cnt+1], d[3])
    test_examples[i] = new_d
    cnt += 2

# %%
# Print some test data again
print(test_examples[0], end='\n\n')
print(test_examples[10], end='\n\n')
print(test_examples[200], end='\n\n')
print(test_examples[3000], end='\n\n')
print(test_examples[-1])
# Out:
# ('ECHO', '102920 | 176 | 2167 |', '_REPORT | 2013-09-23 00:00:00.0 | | PATIENT/TEST INFORMATION: Indication: Pericardial effusion. Height: (in) 68 Weight (lb): 184 BSA (m2): 1.97 m2 BP (mm Hg): 140/80 HR (bpm): 70 Status: Inpatient Date/Time: 2013-09-23 at 10:20 Test: TTE (Focused views) Doppler: No doppler Contrast: None Technical Quality: Adequate | | INTERPRETATION: Findings: LEFT ATRIUM: The left atrium is moderately dilated. The left atrium is elongated. RIGHT ATRIUM/INTERATRIAL SEPTUM: The right atrium is moderately dilated. LEFT VENTRICLE: There is severe symmetric left ventricular hypertrophy. The left ventricular cavity size is normal. Overall left ventricular systolic function is low normal (LVEF 50-55%). LV WALL MOTION: The following resting regional left ventricular wall motion abnormalities are seen: basal inferoseptal - hypokinetic; mid inferoseptal - hypokinetic; basal inferior - hypokinetic; mid inferior - hypokinetic;', 'C0013516')
#
# ('GI', '6281 | 381 | 17672 | DISCHARGE_SUMMARY | 2018-05-22 00:00:00.0 | | | | Admission Date: 2018-05-16 Discharge Date: 2018-05-22 Date of Birth: 1973-02-21 Sex: F Service: SURGERY Allergies: Penicillins / Flagyl Attending:ECHO CASSARD Chief Complaint: Abdominal pain/abcess Major Surgical or Invasive Procedure: Ultrasound guided abdominal drain 2018-05-17 History of Present Illness: 44 yo female transfer here from Wyoming Medical Center complaining of mid abdominal pain and redness. Over the last 2 weeks, she noticed night sweats and subjective fever at home. She was transfered to Pioneer Health Services Of Patrick County per recommendation of her', 'specialist Dr. DILLINGHAM. The CT showed mainly anechoic (cystic) collection in the deep subcutaneous tissues
RCA. Past Medical History: GERD HTN Hypercholesterolemia Retinal detachments s/p multiple retinal surgeries Social History: Not a smoker. Alcohol use -one drink every couple of weeks. No drug use. Family History: No significant history of familial heart disease. Paternal Grandmother had', 'at age 78. Physical Exam: VITALS: T Afebrile HR 55 BP 118/78 RR 15 Sat 98 GENERAL: well developed male in NAD SKIN: no rashes HEAD: NC/AT EYES: EOMI, Anicteric, R pupil located laterally on CORTNEY, L pupil dyssymetric THROAT: No erythema, no tonsillar enlargement, tongue midline NECK: No stiffness, No masses, No LAD, Palpable carotid pulses, no bruits, no JVD CHEST: no supraclavicular or axillary LAD, Lungs Clear to Asculation, No Wheezes/Rhonchi/Crackles HEART: normal PMI, RRR, No Murmurs/Gallops/Rubs BACK: No CVA Tenderness, No spinal tenderness ABDOMEN: Flat, NABS, Soft, No organomegaly, No masses, No guarding, No rebound EXT: No clubbing/cyanosis/edema. Good Pulses. NEURO: oriented to person, place, time Pertinent Results: Admission Labs: 2012-09-09 07:25PM WBC-16.5* RBC-4.35* HGB-14.2 HCT-40.8 MCV-94 MCH-32.7* MCHC-34.8 RDW-12.6 2012-09-09', 'C0027051')
#
# ('ICH', "1000mg (for approx 50kg female) slowly, to prevent risk of dropping BP further and cardiac arrhythmia, then started 100mg q8h. Monitored lytes, coags, cbc, cardiac enzymes. Addressed code status and goals of care via further family discussions. Met with family husband and daughter evening @11:50pm 12-28 and patient's code status was made Comfort Measures Only. Confirmed with NeuroICU attending Dr. FIDEL HAFEMEISTER and ICU resident Dr. BOBBIE BUFFO. Patient was subsequently extubated and passed away overnight from respiratory failure. Family was notified and declined autopsy. Medications on Admission: lasix 20 mg bid lipitor 40 mg qd diovan 160 mg qd labetalol 200 mg bid asa 81 mg carbamazepine 100mg bid Discharge Medications: Discharge Disposition: Expired Discharge Diagnosis:", 'Discharge Condition: Expired WAVA PARRIS MD  Completed by: WENINGER CHU MD  2018-03-23 @ 1548 Signed electronically by: DR. LEIGH MCCULLOGH on: FRI 2018-04-06 4:39 PM (End of Report)', 'C2937358')

# %% [markdown]
# ## Load UMLS specialist data

# %%
umls_eui_name_dict = defaultdict(list)  # EUI -> names (list)
umls_abbr_expansion_dict = defaultdict(list)  # Abbr EUI -> Expansion EUI (list)
umls_abbr_eui_dict = defaultdict(list)  # Abbr -> EUI (list)

with open(lrabr_fpath, 'r', encoding='utf-8') as fd:
    reader = csv.reader(fd, delimiter='|', quotechar=None)
    for i, l in enumerate(reader):
        abbr_eui, abbr, abbr_type, label_eui, label = l[:5]
        if label_eui and abbr_eui:
            if label_eui not in umls_abbr_expansion_dict[abbr_eui]:
                umls_abbr_expansion_dict[abbr_eui].append(label_eui)

        if abbr not in umls_eui_name_dict[abbr_eui]:
            umls_eui_name_dict[abbr_eui].append(abbr)
        if label not in umls_eui_name_dict[label_eui]:
            umls_eui_name_dict[label_eui].append(label)
            
        if abbr_eui not in umls_abbr_eui_dict[abbr]:
            umls_abbr_eui_dict[abbr].append(abbr_eui)
            
print(f'Read {i+1} LRABR records')
print(f'{len(umls_eui_name_dict)} EUIs')
print(f'{len(umls_abbr_eui_dict)} abbrs')
print(f'{len(umls_abbr_expansion_dict)} abbrs')
# Out:
# Read 289314 LRABR records
# 114770 EUIs
# 70336 abbrs
# 40539 abbrs

# %%
# Show some EUI-name mappings
list(umls_eui_name_dict.items())[:10]
# Out:
# [('E0000048', ['AA']),
#  ('E0006859', ['achievement age']),
#  ('E0000204', ['Alcoholics Anonymous']),
#  ('E0356324', ['alcohol abuse', 'alcohol-abuse']),
#  ('E0009858', ['aortic aneurysm']),
#  ('E0009859', ['aortic arch']),
#  ('E0010668', ['ascending aorta']),
#  ('E0356325', ['attendance allowance']),
#  ('E0008570', ['aminoacid', 'amino acid', 'amino-acid']),
#  ('E0010231', ['arachidonic acid'])]

# %%
# Show some Abbr-EUI mappings
list(umls_abbr_eui_dict.items())[:10]
# Out:
# [('AA', ['E0000048', 'E0006420', 'E0356326']),
#  ('AAA', ['E0000049', 'E0000546']),
#  ('AAMD', ['E0000050']),
#  ('A.A.M.D.', ['E0000050']),
#  ('AAT', ['E0000051', 'E0722680']),
#  ('AB', ['E0000052', 'E0565697', 'E0763870']),
#  ('ABC', ['E0000053']),
#  ('ACA', ['E0000055']),
#  ('ACE', ['E0000056', 'E0695741']),
#  ('ACEP', ['E0000057'])]

# %%
# Show some Abbr EUI-Expansion EUI mappings
list(umls_abbr_expansion_dict.items())[:5]
# Out:
# [('E0000048',
#   ['E0006859',
#    'E0000204',
#    'E0356324',
#    'E0009858',
#    'E0009859',
#    'E0010668',
#    'E0356325',
#    'E0008570',
#    'E0010231',
#    'E0010693',
#    'E0009968',
#    'E0007418',
#    'E0430108',
#    'E0008236',
#    'E0420574',
#    'E0071058',
#    'E0071063',
#    'E0448041',
#    'E0007136',
#    'E0006445',
#    'E0598116',
#    'E0598115',
#    'E0598114',
#    'E0598113',
#    'E0598112',
#    'E0598111',
#    'E0598110',
#    'E0598109',
#    'E0598108',
#    'E0759888',
#    'E0006802',
#    'E0066286',
#    'E0006800',
#    'E0598117']),
#  ('E0000049',
#   ['E0429482',
#    'E0429483',
#    'E0429484',
#    'E0429485',
#    'E0429486',
#    'E0356310',
#    'E0356309',
#    'E0006446',
#    'E0598118',
#    'E0588272',
#    'E0561250',
#    'E0598119',
#    'E0598120',
#    'E0598123',
#    'E0598121',
#    'E0598122']),
#  ('E0000050', ['E0000277']),
#  ('E0000051',
#   ['E0500264',
#    'E0500260',
#    'E0007918',
#    'E0500262',
#    'E0500261',
#    'E0010744',
#    'E0515593',
#    'E0515594',
#    'E0515595',
#    'E0515596']),
#  ('E0000052',
#   ['E0010624',
#    'E0338802',
#    'E0009430',
#    'E0000202',
#    'E0430215',
#    'E0008664',
#    'E0009423',
#    'E0565693',
#    'E0565694',
#    'E0565695',
#    'E0565696',
#    'E0724916',
#    'E0303484',
#    'E0413371',
#    'E0724917',
#    'E0724918',
#    'E0008501',
#    'E0724919',
#    'E0006540',
#    'E0006443'])]

# %%
# Normalized abbr (Group)-Orig abbrs mapping
umls_abbr_denorm_dict = defaultdict(list)
for abbr in umls_abbr_eui_dict:
    abbr_norm = normalize_abbr_variation(abbr)
    umls_abbr_denorm_dict[abbr_norm].append(abbr)
print(f'{len(umls_abbr_denorm_dict)} normalized abbrs in LRABR')
# Out:
# 44517 normalized abbrs in LRABR

# %%
list(umls_abbr_denorm_dict.items())[:10]
# Out:
# [('aa', ['AA', 'aa']),
#  ('aaa', ['AAA', 'A.A.A.']),
#  ('aamd', ['AAMD', 'A.A.M.D.']),
#  ('aat', ['AAT']),
#  ('ab', ['AB', 'ab', 'A-B']),
#  ('abc', ['ABC']),
#  ('aca', ['ACA', 'A.C.A.']),
#  ('ace', ['ACE', 'ace', 'Ace', 'ACe']),
#  ('acep', ['ACEP']),
#  ('acs', ['ACS', 'A.C.S.'])]

# %% [markdown]
# ## Dataset Generation

# %% [markdown]
# Each row of the dataset consists of example index, abbreviation, left context, right context, and label CUIs (positive & negative). Here, the labels are written differently in the train and the test set. Specifically, the train dataset has the positive CUI followed by the negative CUIs (the negative CUIs can be empty). On the other hand, instead of the negative CUIs, the test dataset has the candidate CUIs from where an evaluated model should choose its output (the candidate CUIs may not include the positive CUI and also may be empty).
#
# A train example looks like:
# - index: `1996`
# - abbreviation: `EOMs`
# - Left context: `"... The patient was therefore taken back to the operating room for a clipping of the second MCA aneurysm without intraoperative complication. The patient was monitored in the Surgical Intensive Care Unit. She was alert, awake, oriented, complaining of severe headache, moving all extremities."`
# - Right context: `"full, negative drift, a smile was symmetric, IP is 05-18. The patient was then discharged to the floor on 2015-03-20. She has been out of bed and ambulating with Physical Therapy, tolerating a regular diet, and voiding spontaneously. ..."`
# - Positive (correct) CUI: `C0149566`
# - **Negative CUIs**: `C2228439`, `C2228347`
#
# A test example looks like:
# - index: `2`
# - abbreviation: `r/o`
# - Left context: `"166217 | 19154 | 7888 | RADIOLOGY_REPORT | 2012-09-11 17:36:00.0 | C12 CHEST (PORTABLE AP) | | Clip # 348-5236 Actual report | DATE: 2012-09-11 5:36 PM CHEST (PORTABLE AP) 2935 Reason: new hypoxia, fevers, please"`
# - Right context: `"pneumonia Admitting Diagnosis: SKULL FRACTURE;HEAD INJURY;SAH UNDERLYING MEDICAL CONDITION: 65 year old man with REASON FOR THIS EXAMINATION: new hypoxia, fevers, please r/o pneumonia FINAL REPORT CLINICAL HISTORY: A 65-year-old male with hypoxia and fevers. ..."`
# - Positive (correct) CUI: `C0332196`
# - **Candidate CUIs**: `C0332196`, `C2205978`

# %% [markdown]
# ### 1. Training Set
#
# For each annotation of the train set, we assign negative labels (CUI) as all other labels of the examples with same abbreviation group.

# %%
# Training Group-CUI dict
train_group_cuis_dict = {}
for d in train_examples:
    abbr, _, _, cui = d
    abbr_group = normalize_abbr_variation(abbr)
    if not abbr_group in train_group_cuis_dict:
        train_group_cuis_dict[abbr_group] = [cui]
    elif cui not in train_group_cuis_dict[abbr_group]:
        train_group_cuis_dict[abbr_group].append(cui)
        
print(f'{len(train_group_cuis_dict)} groups, {sum([len(v) for k, v in train_group_cuis_dict.items()])} senses')
train_group_cuis_dict
# Out:
# 670 groups, 860 senses
# {'f': ['C0015780', 'C0015671', 'C0553741'],
#  'heent': ['C3494720'],
#  's1': ['C0232223', 'C1261045'],
#  's2': ['C0232230', 'C0018820'],
#  'mca': ['C0149566', 'C1267298'],
#  'acomm': ['C0149562'],
#  'eoms': ['C2228347', 'C0149566', 'C2228439'],
#  'ip': ['CUI-less'],
#  'sob': ['C0013404'],
#  'mibi': ['C0430473', 'C2205978'],
#  'osh': ['CUI-less'],
#  'nl': ['C0205307'],
#  'lvef': ['C0428772'],
#  'cath': ['C0018795', 'C0007430', 'C0879005'],
#  'lmca': ['C0226031'],
#  'lad': ['C0226032', 'C0497156'],
#  'd1': ['C2067351'],
#  'rca': ['C1261316'],
#  'ho': ['C0332119', 'C1510665'],
#  'lgib': ['C0024050'],
#  'asa': ['C0004057'],
#  'qod': ['C0558287'],
#  'mi': ['C0027051'],
#  'exam': ['C0582103', 'CUI-less'],
#  'pe': ['C0031809', 'C0034065'],
#  't': ['C0005903', 'C0578034', 'C0039476', 'C0581269'],
#  'bp': ['C1271104', 'C0005823'],
#  'r': ['C0205090', 'C1291003', 'C0232267', 'C0034642', 'C0035508', 'CUI-less'],
#  'p': ['C0577836', 'C0577802', 'C0030987', 'C0030247'],
#  'sat': ['C0523807', 'C3163851'],
#  'ra': ['C2709070', 'C0225844'],
#  'g': ['CUI-less', 'C0232200', 'C1704242'],
#  'nad': ['C2051415'],
#  'mmm': ['C0517391', 'CUI-less'],
#  'jvd': ['C0425687'],
#  'diff': ['C0332218'],
#  'exp': ['C0231800', 'C1704631'],
#  'cv': ['C0007226', 'C1285180', 'C0436125', 'C0444466'],
#  'rrr': ['C0232188', 'C1291003', 'C0232202'],
#  'abd': ['C0562238', 'C0000726'],
#  'nt': ['C0520959', 'C0573980', 'C0424826', 'CUI-less'],
#  'nd': ['C0424826', 'CUI-less'],
#  'bs': ['C0232693', 'C0035234'],
#  'ext': ['C0436150', 'C0278454'],
#  'neg': ['C0205160'],
#  'mid': ['C0444598'],
#  'lcx': ['C0226037'],
#  'rpda': ['C0500492'],
#  'ef': ['C2700378'],
#  '3vd': ['C0340285'],
#  'cabg': ['C0010055'],
#  'lima': ['C0447054'],
#  'svg': ['C0729538'],
#  'pda': ['C2732720', 'C0013274'],
#  'plb': ['C1185860'],
#  'om': ['C0226040'],
#  'op': ['C1882154', 'C1280659', 'C2071387'],
#  'csru': ['CUI-less', 'C1707306'],
#  'postop': ['C0032790'],
#  'simv': ['C0278335'],
#  'pod': ['CUI-less'],
#  'sp': ['C0231290', 'CUI-less'],
#  'pt': ['C0491338',
#   'C0030705',
#   'CUI-less',
#   'C1720310',
#   'C0949766',
#   'C0086835',
#   'C1533047',
#   'C1997188'],
#  'inr': ['C0525032'],
#  'qd': ['C0332173'],
#  'prn': ['C1883728'],
#  'echo': ['C0013516'],
#  'bsa': ['C0005902'],
#  'hr': ['C0577802', 'C0018810'],
#  'tte': ['C0430462'],
#  'la': ['C0225860'],
#  'lv': ['C0225897', 'CUI-less'],
#  'rv': ['C0225883', 'CUI-less'],
#  'pa': ['C0034052', 'C1996865', 'C0031833'],
#  'intraop': ['C0021891', 'C0456904'],
#  'aaa': ['C0162871'],
#  'tee': ['C0206054'],
#  'laa': ['C0457113'],
#  'lvh': ['C0149721', 'CUI-less'],
#  'as': ['C0003507'],
#  'ar': ['C0003504'],
#  'mr': ['C0026266', 'C0024485'],
#  'tr': ['C0040961'],
#  'pr': ['C0034088', 'C0034086'],
#  'ct': ['C0040405', 'C1274037'],
#  'wo': ['C0332288'],
#  'iv': ['C0348016', 'CUI-less', 'C2228491', 'C1289919'],
#  'ecg': ['C0013798'],
#  'm': ['C0024554', 'C0018808', 'CUI-less'],
#  'na': ['C1272460'],
#  'nebh': ['CUI-less'],
#  'gtube': ['C1546658'],
#  'o2sat': ['C0523807', 'C3163851', 'C0483415'],
#  'vanc': ['C0042313'],
#  'azithro': ['C0052796'],
#  'lac': ['C0428446', 'C0434066', 'C0043246'],
#  'pud': ['C0030920'],
#  'raka': ['C2202462'],
#  'cva': ['C0038454'],
#  'gib': ['C0017181'],
#  'dvt': ['C0149871'],
#  'nh': ['C0028688'],
#  'nc': ['CUI-less', 'C0578008'],
#  'nrb': ['C1960093'],
#  'bl': ['C0238767', 'C0230446'],
#  'assoc': ['C0332281'],
#  'peg': ['C0176751'],
#  'rbka': ['C2202463'],
#  'cdi': ['C2180156'],
#  'l': ['C0205091', 'C0024109'],
#  'le': ['C0023216'],
#  'dp': ['C0226492', 'C1706488'],
#  'cxr': ['C0039985'],
#  'kub': ['C0203102'],
#  'pw': ['C0449450'],
#  'lll': ['C1261077'],
#  'must': ['C1532006'],
#  'svo2': ['C0428176'],
#  'bps': ['C1271104'],
#  'recd': ['C1514756'],
#  'ns': ['C0445115'],
#  'stim': ['C1292856'],
#  'apc': ['C0483249'],
#  'pna': ['C0032285'],
#  'cvp': ['C1321771'],
#  'ecoli': ['C0014834'],
#  'dw': ['C2584313'],
#  'cmo': ['C0030231'],
#  'hd2': ['CUI-less'],
#  'riss': ['C0557977'],
#  'qid': ['C0585291'],
#  'fs': ['C0457575'],
#  'gi': ['C0521362', 'C0587681', 'C0017187', 'C2609454', 'C0012240'],
#  'hepsc': ['CUI-less'],
#  'mva': ['C2939181'],
#  'orif': ['C1297885'],
#  'loc': ['C0234425', 'C0853202'],
#  'co': ['C0277786'],
#  'aaox3': ['C2051416'],
#  'perrla': ['C2143306'],
#  'cta': ['CUI-less', 'C2703057', 'C2106960'],
#  'card': ['C0436125', 'CUI-less', 'C0007226'],
#  'lue': ['C0230330'],
#  'rom': ['C2607871'],
#  'cspine': ['C0728985'],
#  'tls': ['C1443270'],
#  'l5': ['C0223552'],
#  'xr': ['C0043303'],
#  'ue': ['C1140618'],
#  'rtibfibxr': ['C2061507'],
#  'ems': ['C0013961'],
#  'fx': ['C0016658', 'CUI-less'],
#  'omfs': ['C0812928'],
#  'hct': ['C0518014', 'C0018935'],
#  'or': ['C0029064'],
#  'sma': ['C0162861'],
#  'prbcs': ['C2316467'],
#  'er': ['C0583237', 'C0562508', 'C3475492'],
#  'pcp': ['CUI-less', 'C0033131'],
#  'ap': ['C1999039', 'C1827496'],
#  'sda': ['CUI-less', 'C1553165'],
#  'cvl': ['C1145640'],
#  'ij': ['C0226550', 'C1550269'],
#  'preop': ['C0033061', 'C0445204', 'C2004312'],
#  'cad': ['C1956346'],
#  'ica': ['C0007276'],
#  'cca': ['C0162859'],
#  'eca': ['C0007275'],
#  'icacca': ['C1316331'],
#  'mri': ['C0024485'],
#  'mra': ['C0243032'],
#  'nihss': ['C1697238'],
#  'pta': ['CUI-less', 'C0559269'],
#  'adls': ['C0001288'],
#  'vitals': ['C0518766'],
#  'sao2': ['C3163851', 'C0483415'],
#  'at': ['CUI-less'],
#  'w': ['C0043144'],
#  'c': ['C0149651', 'C0010520', 'C0205064', 'C2116810', 'C1979874'],
#  'e': ['C0013604', 'C0013832'],
#  'perrl': ['C2143305'],
#  'vff': ['CUI-less'],
#  'eomi': ['C2228439', 'C0702182', 'CUI-less'],
#  'ua': ['C0042014'],
#  'nchct': ['C2321568'],
#  'eeg': ['C0013819'],
#  'bid': ['C0585361', 'C0558287'],
#  'uti': ['C0042029'],
#  'dnr': ['C0582114'],
#  'gcs': ['C0017594'],
#  'afib': ['C0004238'],
#  'ptt': ['C0030605', 'C1318441'],
#  'npo': ['C0419179'],
#  'ng': ['C3282907'],
#  'atn': ['C0022672'],
#  'tsh': ['C0202230'],
#  'hba1c': ['C0202054'],
#  'disp': ['C0743223'],
#  'avr': ['C0003506', 'C0003504'],
#  'st': ['C0038257', 'C0242823'],
#  'redo': ['CUI-less'],
#  'turp': ['C0040771'],
#  'gen': ['C0436117'],
#  'neuro': ['C0027853', 'C0205494'],
#  'ekg': ['C0013798'],
#  'temp': ['C0039476', 'C0039484', 'C0578034'],
#  'chf': ['C0018802'],
#  'biv': ['C0699808'],
#  'ccy': ['C0008320'],
#  'etoh': ['C0001962'],
#  'pod1': ['CUI-less'],
#  'pod3': ['CUI-less'],
#  'pod4': ['CUI-less'],
#  '2d': ['C0013524', 'C1705052'],
#  'aova': ['C0428817'],
#  'hcfa': ['C0041718'],
#  'cpb': ['C0007202'],
#  'ai': ['C0003504'],
#  'fxn': ['C0542341'],
#  'pm': ['C0178611'],
#  'lvot': ['C0225912'],
#  'vsd': ['C0018818'],
#  'emts': ['C0013963'],
#  'coag': ['C0009118'],
#  'fluoro': ['C0016356', 'C0016353'],
#  'esld': ['C0745744'],
#  'ivc': ['C0042458'],
#  'tia': ['C0007787'],
#  'av': ['C0004245', 'C0003501', 'C0450109'],
#  '02': ['C0030054'],
#  't12': ['C0223371'],
#  'l1': ['C0223492'],
#  'l4': ['C0223537'],
#  'l3': ['C0223522'],
#  'pco2': ['C0391839'],
#  't8': ['C0446426'],
#  't9': ['C0446427', 'C0501684'],
#  'psa': ['C0138741'],
#  'rr': ['C1291003', 'C0231832'],
#  'from': ['C2008892'],
#  'nml': ['C0205307'],
#  'nabs': ['C0278005'],
#  'ppd': ['C0034131', 'C0750582'],
#  'ards': ['C0035222'],
#  'mv': ['C0026264'],
#  'mvp': ['C0026267'],
#  'rul': ['C1261074'],
#  'abg': ['C0428166', 'C0150411'],
#  'cap': ['C0694549'],
#  'bal': ['C1535502', 'C0006279'],
#  'hiv': ['C1321876', 'C1717908', 'C0019682', 'C1399816', 'C0476550'],
#  'ag': ['C1509129'],
#  'bcxr': ['C0200949'],
#  'ucxr': ['C0848716'],
#  'afb': ['C0483226'],
#  'ldh': ['C0202113'],
#  'bili': ['C0201913'],
#  'hapto': ['CUI-less'],
#  'b12': ['C0042845'],
#  'cat': ['C0040405'],
#  'hpi': ['C0262512'],
#  'sah': ['C0038525'],
#  'pmhx': ['C0455458'],
#  'hx': ['C0019664'],
#  'wd': ['C2051419', 'C0087169'],
#  'wn': ['C2051421'],
#  'extrem': ['C0436150'],
#  'i': ['C2228468', 'C0205266', 'C0184898'],
#  'ii': ['C2228469', 'C0029130'],
#  'iii': ['C2228464'],
#  'vi': ['C2228416'],
#  'v': ['C2228490', 'C0518766', 'C0042963', 'C0733956'],
#  'vii': ['C2228441', 'C0015462', 'C0733959'],
#  'viii': ['C2228510'],
#  'ix': ['C2228445', 'C0017679'],
#  'x': ['C2228508'],
#  'xi': ['C2228484'],
#  'xii': ['C2228447', 'C0020614'],
#  'icu': ['C0021708'],
#  'ciwa': ['C0814193'],
#  'eval': ['C0220825'],
#  'picc': ['C0179740'],
#  'aha': ['C0002458'],
#  'us': ['C0041618'],
#  'pp': ['C0086839', 'C0445174'],
#  'dc': ['C0012358', 'C0442831', 'C1706472'],
#  'ro': ['C0332196', 'C2205978'],
#  'ptx': ['C0032326', 'CUI-less'],
#  'peumonia': ['C0032285'],
#  'dart': ['CUI-less'],
#  'asd': ['C0018817'],
#  'ps': ['C1956257', 'C0419008'],
#  'addl': ['C1524062'],
#  'pel': ['C0030797'],
#  'lowerext': ['C0023216'],
#  'agram': ['C0002978'],
#  'lgi': ['C0226875'],
#  'rbc': ['C0948706'],
#  'amt': ['C0805077'],
#  'cpt': ['C1138431', 'CUI-less'],
#  'lower': ['C0023216'],
#  'lo': ['C0023216'],
#  'fr': ['C0580793'],
#  'sos': ['CUI-less'],
#  'cont': ['CUI-less', 'C2091305'],
#  'lfts': ['C0023901'],
#  'tpn': ['C0030548'],
#  'po': ['C1527415', 'C0205531'],
#  'mvc': ['C2939181'],
#  'pulm': ['CUI-less', 'C0024109'],
#  'trach': ['C0184159', 'C0040590'],
#  'speniclac': ['C0347636'],
#  'rehab': ['C0034991'],
#  'c2': ['C0728985'],
#  'pmh': ['C0455458'],
#  'sh': ['C0679833', 'C0424945'],
#  'cigs': ['C0677453'],
#  'fh': ['C0241889'],
#  'tc': ['C0039476', 'C0578034'],
#  'fi02': ['C0428167'],
#  'mvmt': ['C0026649'],
#  'resp': ['C0035237', 'C0599324', 'C0521346'],
#  'd': ['C0205222', 'C0011991', 'C0013103'],
#  'ms': ['C0278060', 'C0026269'],
#  'cn': ['C0010268'],
#  'rue': ['C0230329'],
#  'rle': ['C0230415'],
#  'id': ['C1555764'],
#  'heme': ['C1313875', 'C0475180'],
#  'dced': ['C1444662'],
#  'fu': ['C1522577'],
#  'wlmob': ['CUI-less'],
#  'egd': ['C0079304'],
#  'ogt': ['C0400365'],
#  'vats': ['C0752151'],
#  'svc': ['C0042459'],
#  'lat': ['C0205093'],
#  'cpp': ['C0428713'],
#  'hepc': ['C0019196'],
#  'alkphos': ['C0201850'],
#  'hydro': ['C0020295'],
#  'wbc': ['C0200632', 'C0427512'],
#  'niddm': ['C0011860'],
#  'htn': ['C0020538'],
#  'tah': ['C0404079'],
#  'vss': ['C0277803'],
#  'perla': ['C1270988'],
#  'bilat': ['C0238767'],
#  'a': ['C0004339'],
#  'vanco': ['C0042313'],
#  'gent': ['C0017436'],
#  'dcd': ['C1444662', 'C0438953'],
#  'mrsa': ['C0343401', 'C1265292'],
#  'jp': ['C1272738'],
#  'cpap': ['C0199451'],
#  '02sat': ['C0523807'],
#  'q': ['C1720374'],
#  'timi': ['C3272266'],
#  's3': ['C0232237'],
#  's4': ['C0232241'],
#  'qhs': ['C1275563'],
#  'ace': ['C0003015'],
#  'brat': ['C0301572'],
#  'cks': ['C0201973'],
#  'ctcspinewocontrast': ['C2026920'],
#  'mdct': ['CUI-less'],
#  'c3': ['CUI-less'],
#  'ccu': ['C0587446', 'C2065802'],
#  'ldl': ['C0023823'],
#  'hdl': ['C0023821'],
#  'vna': ['C0042799', 'CUI-less'],
#  'ptinr': ['C1821762'],
#  'esr': ['C0086250', 'C1176468'],
#  'chi': ['C0085094'],
#  'ett': ['C0336630'],
#  'port': ['CUI-less'],
#  'rsc': ['CUI-less'],
#  'exlap': ['C0745645'],
#  'nsclc': ['C0007131'],
#  'ffp': ['C0016709'],
#  'prbc': ['C2316467'],
#  'ficu': ['CUI-less'],
#  'dni': ['C0742532'],
#  'ros': ['C0489633', 'C1827907'],
#  'fna': ['C1510483'],
#  'pet': ['C0032743'],
#  'xrt': ['C0436209'],
#  'lg': ['C0549177'],
#  'tbna': ['C1883418'],
#  'met': ['C1522484'],
#  'meds': ['C0013227'],
#  'lbp': ['C0024031'],
#  'pkyr': ['C1277691'],
#  'ctab': ['CUI-less'],
#  'wwp': ['CUI-less'],
#  'aox3': ['C2051416'],
#  'ncslc': ['C0007131'],
#  'sats': ['C0523807', 'C3163851', 'C0483415', 'C0428174'],
#  'vf': ['C0042510'],
#  'hypo': ['C0086439'],
#  'tpa': ['C0535245'],
#  'ha': ['C0018681'],
#  'vs': ['C0518766'],
#  'sem': ['C0694547'],
#  'hsm': ['C0019214'],
#  'lt': ['C0423553', 'CUI-less'],
#  'scm': ['C0224153'],
#  'hocm': ['C0007194'],
#  'cw': ['C0332290'],
#  'lab': ['C0022877'],
#  'spect': ['C0040399'],
#  'edv': ['C0042509'],
#  'si': ['C2364109', 'C0424000'],
#  'uc': ['C0009324'],
#  'copd': ['C0024117'],
#  'sbp': ['C1306620', 'CUI-less', 'C2062979'],
#  'ivf': ['C1289919'],
#  'pulse': ['C0232117'],
#  'pmibi': ['CUI-less'],
#  'retic': ['C0035286'],
#  'mdi': ['C0993596'],
#  'do': ['CUI-less', 'C0012634'],
#  'gerd': ['C0017168'],
#  'fem': ['C0232148'],
#  'nsu': ['C0587688'],
#  'bipap': ['C1458059'],
#  'mibg': ['C0860839'],
#  'ppn': ['C1527386'],
#  'fena': ['C1955481'],
#  'tele': ['C0039451'],
#  't1w': ['CUI-less'],
#  't2w': ['CUI-less'],
#  'stir': ['CUI-less'],
#  'gre': ['CUI-less'],
#  't1': ['C0501486', 'CUI-less'],
#  't2': ['C0501591'],
#  't6': ['C0501675'],
#  'odd': ['C0029944'],
#  'od': ['C0029944'],
#  'ect': ['C0013806'],
#  'dts': ['C0001957'],
#  'ssi': ['CUI-less'],
#  'tob': ['C0040329'],
#  'mm': ['C0026724'],
#  'tox': ['C0040541'],
#  'pscyh': ['C0205486'],
#  'asp': ['C0700198'],
#  'abx': ['C0003232'],
#  'ah': ['C0233762'],
#  'outpt': ['C0029921'],
#  'gtt': ['C0017741', 'C0991568'],
#  'sc': ['C1522438'],
#  'ppi': ['C0358591'],
#  'mvi': ['C0978787'],
#  'o2': ['C0030054', 'C3163851'],
#  'ce': ['CUI-less'],
#  'tid': ['C0556984'],
#  'crp': ['C0201657'],
#  '2u': ['C0439148'],
#  '5u': ['C0439148'],
#  'plts': ['C0005821'],
#  'epiinject': ['C0730534'],
#  'cp': ['C0008031'],
#  'etohism': ['C0001973'],
#  'tms': ['C0041445'],
#  'ln': ['C0024204'],
#  'pmi': ['C2958985'],
#  's': ['C0205358'],
#  'abdus': ['C0203464'],
#  'ngt': ['C0085678'],
#  'ruq': ['C0439734'],
#  'dt': ['C0001957'],
#  'nsvt': ['C2919575'],
#  'mg': ['C0024467'],
#  'k': ['C0032821', 'C0042878'],
#  'csu': ['C0587672', 'C0583299'],
#  'tmax': ['C0488019'],
#  'jvp': ['C0428897'],
#  'pfo': ['C0016522'],
#  'osa': ['C0520679'],
#  'aao': ['CUI-less'],
#  'pod2': ['CUI-less'],
#  'pod6': ['CUI-less'],
#  'bun': ['C0005845'],
#  'd50': ['C0308816'],
#  'pos': ['C0205531'],
#  'sscp': ['C0742310'],
#  'rvad': ['C1456079'],
#  'ecmo': ['C0015357'],
#  'stemi': ['C1303258', 'C1561918'],
#  'cathlab': ['C1707294'],
#  'iabp': ['C0702122'],
#  'pea': ['C1960149'],
#  'acls': ['C0887907'],
#  'cfa': ['C0447105'],
#  'cfv': ['C1275667'],
#  'eia': ['C1269019'],
#  'hit': ['C0272285'],
#  'vad': ['C0184269'],
#  'vac': ['C1956080'],
#  'optho': ['C0587689'],
#  'fluc': ['C0082607'],
#  'ceftaz': ['C0007559', 'C0007546'],
#  'thr': ['C0040508'],
#  'avn': ['C0027543'],
#  'dm2': ['C0011860'],
#  'cd4': ['C2698595'],
#  'esrd': ['C2316810'],
#  'hd': ['C0019004', 'CUI-less'],
#  'diastdysf': ['C0520863'],
#  'sobx': ['C0013404'],
#  'n': ['C0027497', 'C0392209'],
#  'o2sats': ['C3163851', 'C0483415', 'C0523807'],
#  'ptca': ['C2936173'],
#  'ettmibi': ['C2733235'],
#  'cd': ['C2698595'],
#  'nsaid': ['C0003211'],
#  'ac': ['C2223981'],
#  'tachy': ['C0039231'],
#  'mvt': ['C0026649'],
#  'avf': ['C0003855'],
#  'pts': ['C0030705'],
#  'cx': ['C0430400'],
#  'vre': ['C1265175'],
#  'dm': ['C0011849'],
#  'cdiff': ['C2724338', 'C0343386'],
#  'bph': ['C0005001'],
#  'pacu': ['C0034871'],
#  'vicu': ['CUI-less'],
#  'subcu': ['C1522438'],
#  'hyperchol': ['C0020443'],
#  'brbpr': ['C0018932'],
#  'rx': ['C0304227'],
#  'ca': ['C0006826', 'C0443758'],
#  'cspinect': ['C0412650'],
#  '5': ['C0223552'],
#  'im': ['C2732619'],
#  'tlso': ['C2014892'],
#  'pap': ['C0577534'],
#  'os': ['C0227833'],
#  'q4h': ['C0585324'],
#  'fio2': ['C0428167'],
#  'fvc': ['C1879462'],
#  'mae': ['C0561980'],
#  'rap': ['C0456165'],
#  'cts': ['C0040405'],
#  'inspir': ['C0004048'],
#  'palp': ['C0030252'],
#  'timiiii': ['C3272287'],
#  'tib': ['C1279118'],
#  'fib': ['C1281580'],
#  'pca': ['C0078944', 'C0030625'],
#  'ot': ['C0028807'],
#  'rt': ['C0205090'],
#  'ao': ['C2051416'],
#  'ious': ['C2368278'],
#  'jtube': ['C0879216'],
#  'j': ['C0595821'],
#  'psh': ['C0744961'],
#  'csection': ['C0007876'],
#  'ttp': ['CUI-less'],
#  'jeje': ['CUI-less'],
#  'rijcvl': ['C2026111'],
#  'ercp': ['C0008310'],
#  'fen': ['CUI-less'],
#  'rlq': ['C0439736'],
#  'hop': ['C0227579'],
#  'stat': ['C0205548'],
#  'h2o': ['C0043047'],
#  'io': ['C0886111'],
#  'irregirreg': ['C2079307'],
#  'nitro': ['C0017887'],
#  'lul': ['C1261076'],
#  'ctabdwwoc': ['C2041480'],
#  'ctpelviswwoc': ['C2051896'],
#  'sch': ['CUI-less'],
#  'fluor': ['C0016356'],
#  'guid': ['C0302614'],
#  'plct': ['C1524072'],
#  'replct': ['C0559956'],
#  'vas': ['C1801960'],
#  'percggjtubeplmt': ['C1964211', 'C2053003'],
#  'gj': ['C0399839'],
#  '16fr': ['C0580793'],
#  '18fr': ['C0580793'],
#  'map': ['C0513528'],
#  'ptc': ['C0203085'],
#  'cea': ['C0201933'],
#  'ir': ['C0034602', 'C2826145'],
#  'lca': ['C0484519'],
#  'petct': ['C3178842'],
#  'dfa': ['C1707759'],
#  'ddx': ['C0011906'],
#  'pth': ['C0202159'],
#  'pvd': ['C0085096'],
#  'regurg': ['C2004489'],
#  'levo': ['C0282386'],
#  'icd': ['C0162589'],
#  'lle': ['C0230416', 'C0239340'],
#  'wnl': ['CUI-less'],
#  'pelvis': ['C0030797'],
#  'utis': ['C0042029'],
#  'strep': ['C0038402'],
#  'sirs': ['C0242966'],
#  'ush': ['C1442488'],
#  'clinda': ['C0008947'],
#  'pcng': ['C0030827'],
#  'ig': ['C0085297'],
#  'lh': ['C0220870'],
#  'lmp': ['C0425932'],
#  'sochx': ['C0679833'],
#  'lr': ['C0439757'],
#  'amls': ['C0206633'],
#  'aml': ['C0206633'],
#  'peng': ['C0030827'],
#  'pcn': ['C0220892'],
#  'nebs': ['C0027524'],
#  'proph': ['C0199176'],
#  'adat': ['C1828389'],
#  'lytes': ['C0013832'],
#  'cardiapulm': ['C0553534'],
#  'acove': ['CUI-less'],
#  'nph': ['C0021658'],
#  'qam': ['C0585329'],
#  'qpm': ['C0585330'],
#  'csf': ['C0007806'],
#  'dxd': ['C0011900'],
#  'lp': ['C2186430'],
#  'aotimes3': ['C2051416'],
#  'infxn': ['C0021311'],
#  'ues': ['C1140618', 'CUI-less'],
#  'les': ['C0023216'],
#  'legext': ['CUI-less'],
#  'df': ['CUI-less'],
#  'pf': ['C0231784'],
#  'fnf': ['C0234291'],
#  'evd': ['C3161261'],
#  'lm': ['C0751297'],
#  'it': ['CUI-less'],
#  'tmz': ['C0076080'],
#  'ceft': ['C0007559'],
#  'abxs': ['C0003232'],
#  'ss': ['CUI-less'],
#  'nsg': ['C0028698'],
#  'bm': ['C0011135'],
#  'rl': ['C0445232'],
#  'legflex': ['CUI-less'],
#  'pica': ['C0149573'],
#  'haart': ['C0887947'],
#  'cvd': ['C0007222'],
#  'b': ['C0238767'],
#  'angio': ['C0002971'],
#  'gdc': ['CUI-less'],
#  'lenis': ['C2021598'],
#  'me': ['C0242485'],
#  'hepb': ['C0019163'],
#  'tof': ['C2348791'],
#  'haste': ['CUI-less'],
#  'vibe': ['CUI-less'],
#  'cect': ['CUI-less'],
#  'peep': ['C3494516'],
#  'pict': ['C0441469'],
#  'abdpel': ['C1508499'],
#  'tx': ['C0040732'],
#  'asctes': ['C0003962'],
#  'rny': ['C0002804'],
#  'tb': ['C0368753'],
#  'rbbb': ['C0085615'],
#  'gsw': ['C0043252'],
#  'aicd': ['C0972395']}

# %%
group_snum_counter = Counter([len(v) for k, v in train_group_cuis_dict.items()])
print(f'Number of senses in training set: {group_snum_counter}')
# Out:
# Number of senses in training set: Counter({1: 537, 2: 97, 3: 24, 4: 7, 5: 3, 6: 1, 8: 1})

# %%
# Training data output
num_negs = 7
cnt = 0
example_snum_counter = Counter()
print(f'Write training data to {train_output_fpath}')
with open(train_output_fpath, 'w', encoding='utf-8') as f_out:
    writer = csv.writer(f_out, delimiter='\t', quotechar=None)
    writer.writerow(['index', 'group', 'left', 'right', 'label'] + [f'neg_{i}' for i in range(num_negs)])
    for d in train_examples:
        abbr, left, right, cui = d
        abbr_group = normalize_abbr_variation(abbr)
        cuis = train_group_cuis_dict[abbr_group]
#         if len(cuis) == 1:  # Skip if there's only one sense for this abbr(group)
#             continue
        cui_label = cui
        cui_negs = [c for c in cuis if c != cui]
        while len(cui_negs) < num_negs:
            cui_negs.append(' ')
        writer.writerow([cnt, abbr, left, right, cui_label] + cui_negs)
        cnt += 1
        example_snum_counter[len(cuis)] += 1
# Out:
# Write training data to ../data/sc13t2/train.tsv

# %%
example_snum_counter
# Out:
# Counter({3: 302, 1: 1920, 2: 1276, 4: 102, 6: 57, 8: 104, 5: 44})

# %%
# Training data output (for evaluation)
num_train = 4
cnt = 0
print(f'Write training data (in the format of the test data) to {train_output_fpath2}')
with open(train_output_fpath2, 'w', encoding='utf-8') as f_out:
    writer = csv.writer(f_out, delimiter='\t', quotechar=None)
    writer.writerow(['index', 'group', 'left', 'right', 'label'] + [f'train_{i}' for i in range(num_train)])
    for d in train_examples:
        abbr, left, right, cui = d
        abbr_group = normalize_abbr_variation(abbr)
        train_cuis = train_group_cuis_dict[abbr_group]
        writer.writerow([cnt, abbr, left, right, cui] + train_cuis + [] * (num_train - len(train_cuis)))
        cnt += 1
# Out:
# Write training data (in the format of the test data) to ../data/sc13t2/train_test.tsv

# %% [markdown]
# ### 2. Test Set
#
# First, we retrive the labels of unseen normalized abbrs (or unseen abbr groups) using LRABR and MetaMap. And then we choose the candidate CUIs for each test example as follows:
# - If the abbr group is seen (in the train set) -> Use the CUIs from train set
# - If the abbr group is unseen & found in LRABR -> Use CUIs from LRABR
# - If the abbr group is unseen & not found in LRABR -> No candidate CUIs (always incorrect on this example)

# %%
# Test Group-CUI dict
test_group_cuis_dict = {}
for d in test_examples:
    abbr, _, _, cui = d
    abbr_group = normalize_abbr_variation(abbr)
    if not abbr_group in test_group_cuis_dict:
        test_group_cuis_dict[abbr_group] = [cui]
    elif cui not in test_group_cuis_dict[abbr_group]:
        test_group_cuis_dict[abbr_group].append(cui)
        
print(f'{len(test_group_cuis_dict)} groups, {sum([len(v) for k, v in test_group_cuis_dict.items()])} senses')
test_group_cuis_dict
# Out:
# 704 groups, 884 senses
# {'echo': ['C0013516'],
#  'bsa': ['C0005902'],
#  'bp': ['C1271104', 'C0005823'],
#  'hr': ['C0577802', 'C0018810'],
#  'tte': ['C0430462'],
#  'lvef': ['C0428772'],
#  'lv': ['C0225897'],
#  'mr': ['C0026266', 'C0024485'],
#  'f': ['C0015780', 'CUI-less', 'C0015967'],
#  'gi': ['C0521362', 'C0017187', 'C2609454'],
#  'ct': ['C0040405', 'C0008034', 'C1274037', 'CUI-less'],
#  'sp': ['C0231290'],
#  'etoh': ['C0001962', 'CUI-less'],
#  'exam': ['C0582103'],
#  'vs': ['C0518766'],
#  'gen': ['C0436117'],
#  'nad': ['C2051415'],
#  'cta': ['CUI-less', 'C1536105'],
#  'bilat': ['C0238767'],
#  'cv': ['C0436125', 'C0007222', 'C0007226'],
#  'rrr': ['C0232185', 'C0232188', 'C0513693'],
#  'm': ['C0018808', 'CUI-less', 'C0024554', 'C0026591'],
#  'r': ['C0232267', 'C0205090', 'C0034642', 'C0035508', 'C0231832'],
#  'g': ['C0232200', 'C1704242'],
#  'abd': ['C0562238', 'C0000726'],
#  'musc': ['C0475091'],
#  'neuro': ['C0027853',
#   'C0221571',
#   'C0205494',
#   'C0587475',
#   'C0027855',
#   'C0587591'],
#  'aox3': ['C1961840'],
#  'us': ['C0041618', 'C1875843'],
#  'icu': ['C0021708'],
#  'ivf': ['C1289919'],
#  'picc': ['C0179740', 'C2049629'],
#  'avr': ['C0003506'],
#  'pca': ['C0078944', 'C0149576'],
#  'pacu': ['C0034871'],
#  's1': ['C0232223', 'C0446438'],
#  's2': ['C0232230'],
#  'rehab': ['C0034991'],
#  'sob': ['C0013404'],
#  'le': ['C0023216'],
#  'gb': ['C0018378'],
#  'cxr': ['C0039985'],
#  'chf': ['C0018802'],
#  'uop': ['C0232856'],
#  'wbc': ['C0427512', 'C0023508'],
#  'dvt': ['C0149871'],
#  'ekg': ['C0013798', 'C1623258'],
#  'av': ['C1389019', 'C0004247', 'C0450109'],
#  'bnp': ['C1095989'],
#  'abg': ['C0150411'],
#  'kub': ['C1979912'],
#  'htn': ['C0020538'],
#  'afib': ['C0004238'],
#  'cr': ['C0302272', 'C0010294', 'C0201975'],
#  'ho': ['C0332119'],
#  'gerd': ['C0017168'],
#  'psa': ['C0138741'],
#  'bx': ['C0005558'],
#  'dm': ['C0011849'],
#  'pgm': ['C1273524'],
#  'pe': ['C0031809', 'C0034065'],
#  'tm': ['C0039476', 'C2348796'],
#  'tc': ['C0039476', 'C0578034'],
#  'rr': ['C0231832', 'C1291003'],
#  'o2': ['C0030054', 'C3163851'],
#  'nc': ['CUI-less', 'C0179574'],
#  'heent': ['C3494720'],
#  'mmm': ['C0517391'],
#  'at': ['CUI-less'],
#  'mmw': ['CUI-less'],
#  'lad': ['C0497156', 'C0226032'],
#  'cor': ['C0436125'],
#  'pulm': ['C0599324', 'C2709248'],
#  'bl': ['C0238767', 'C0230446', 'C0225754'],
#  'rml': ['C1305136'],
#  'bs': ['C0232693', 'C0035234'],
#  'ext': ['C0436150'],
#  'wwp': ['CUI-less'],
#  'dp': ['C1706488', 'C0226492'],
#  'pt': ['C1720310',
#   'C0030705',
#   'C0086835',
#   'C0949766',
#   'C0033707',
#   'C1997188'],
#  'cn': ['C0010268'],
#  'ii': ['C0029130', 'C2228469'],
#  'xii': ['C0020614', 'C2228447'],
#  'derm': ['C0436149'],
#  'ra': ['C2709070', 'C0225844', 'C0456165'],
#  'pna': ['C0032285'],
#  '02sat': ['C0523807'],
#  '02': ['C0030054'],
#  'les': ['C0023216'],
#  'bun': ['C0005845'],
#  'cre': ['C0302272'],
#  'hct': ['C0518014', 'C2004297'],
#  'pcp': ['C0033131', 'C0032305'],
#  'prbc': ['C2316467'],
#  'fen': ['CUI-less', 'C1446385'],
#  'ef': ['C2700378', 'C0428772', 'C2825171'],
#  'meds': ['C0033081', 'C0013227', 'C0025118'],
#  'cath': ['C0007430', 'C0085590'],
#  'tee': ['C0206054'],
#  'ccu': ['C0587446', 'C0010066'],
#  'lar': ['C1282272'],
#  'echos': ['C0013516'],
#  'bph': ['C1704272'],
#  'l': ['C0205091'],
#  'eomi': ['CUI-less', 'C2228439'],
#  'nl': ['C0205307'],
#  'jvd': ['C0425687'],
#  'op': ['C1882154', 'C0029921', 'C1280659'],
#  'avblock': ['C0004245'],
#  'preop': ['C0445204', 'CUI-less'],
#  'egd': ['C0079304'],
#  'labs': ['C0696211', 'C0587081'],
#  'po': ['C0205531', 'C0001563', 'C1527415'],
#  'iv': ['C0348016', 'C2228491'],
#  'turp': ['C0040771'],
#  'cad': ['C1956346', 'C0010068'],
#  'dps': ['C1706488'],
#  'pts': ['C1720310', 'C0030705'],
#  't': ['C0039476', 'C0578034'],
#  'vna': ['CUI-less', 'C0042799'],
#  'acei': ['C0003015'],
#  'dced': ['C1444662', 'C0030685'],
#  'cva': ['C0038454'],
#  'pafib': ['C0235480'],
#  'sch': ['C0003630'],
#  'cpt': ['C1138431', 'C0199467'],
#  'fluor': ['C0016356'],
#  'guid': ['CUI-less'],
#  'plct': ['C1524072'],
#  'replct': ['C0559956'],
#  'remove': ['C1883720'],
#  'cent': ['C0205099'],
#  'mid': ['C0993745', 'C0444598'],
#  'd': ['C0190979', 'C0205222'],
#  'nsclc': ['C0007131'],
#  'svc': ['C0042459'],
#  'osh': ['CUI-less'],
#  't2dm': ['C0011860'],
#  'sbp': ['C1306620', 'C0871470'],
#  'rij': ['C0501117'],
#  'neo': ['CUI-less', 'C0031469'],
#  'nsr': ['C0232202', 'C1960147'],
#  'rle': ['C0230415'],
#  'vanco': ['C0042313'],
#  'wu': ['C0750430'],
#  'ad': ['C0002395'],
#  'asa': ['C0004057'],
#  'lll': ['C1261077'],
#  'nsrs': ['C0232202'],
#  'ros': ['C1827907', 'C0489633'],
#  'cp': ['C0008031'],
#  'doe': ['C0231807'],
#  'pnd': ['C0013405', 'C1956415'],
#  'ptca': ['C2936173'],
#  'perrla': ['C2143306'],
#  'mm': ['C0026724'],
#  'jvp': ['C0428897'],
#  'sem': ['C0694547'],
#  'rusb': ['C2230288'],
#  'ctab': ['CUI-less'],
#  'nt': ['C0573980', 'C0017887'],
#  'nd': ['C0424826'],
#  'c': ['C0149651', 'C0010520', 'C2116810', 'C0085593', 'C0009054'],
#  'e': ['C0013604'],
#  'rom': ['C2607871'],
#  '2d': ['C0013524'],
#  'prelim': ['C1548161'],
#  'bb': ['C1277233'],
#  'ekgs': ['C0013798'],
#  'trop': ['C0523952'],
#  'hctz': ['C0020261'],
#  'hydral': ['C0020223'],
#  'gtt': ['C0991568'],
#  'lab': ['C0022877'],
#  'ivs': ['C0021909'],
#  'tsh': ['C0202230'],
#  'rpr': ['C0201405'],
#  'b12': ['C0202252'],
#  'svg': ['C0729538'],
#  'pda': ['C0013274'],
#  'irreg': ['C0205271'],
#  'wdwn': ['C2051419'],
#  'ncat': ['CUI-less'],
#  'perrl': ['C2143305'],
#  'from': ['CUI-less'],
#  'w': ['C0043144'],
#  'mae': ['C2222207'],
#  'rv': ['C0225883', 'C1269891'],
#  'cabg': ['C0010055'],
#  'mvr': ['C0026268'],
#  'csru': ['CUI-less', 'C1707306'],
#  'sdu': ['C2112585'],
#  'postop': ['C0032790'],
#  'hit': ['C0272285'],
#  'inr': ['C0525032'],
#  'pmh': ['C0455458'],
#  'p': ['CUI-less', 'C0577836', 'C0232117'],
#  'tah': ['C0404079'],
#  'bso': ['C0195495'],
#  'co2': ['C0007012'],
#  'pod': ['C0032790', 'CUI-less'],
#  'ph': ['C0020283'],
#  'fib': ['C0004238'],
#  'ep': ['C0430467', 'C0013865'],
#  'lbbb': ['C0023211'],
#  'chb': ['C0151517'],
#  'spo2': ['C0428179'],
#  'rul': ['C1261074'],
#  'lmca': ['C0226031'],
#  'dc': ['C0030685', 'C1444662', 'C1548175'],
#  'ms': ['C0278060', 'C0026269'],
#  'mca': ['C0149566'],
#  'ij': ['C0226550'],
#  'nml': ['C0205307'],
#  'ue': ['C1140618'],
#  'lp': ['C0200378', 'C0553794'],
#  'vdrl': ['C2229891'],
#  'hsv': ['C0319232'],
#  'afb': ['C0004238'],
#  'cx': ['C0430400', 'C1880089', 'C0430402'],
#  'neg': ['C0205160'],
#  'fio2': ['C0428167'],
#  'eom': ['C0702182'],
#  'nabs': ['CUI-less', 'C0278005'],
#  'hsm': ['C0019214'],
#  'rbbb': ['C0085615'],
#  'mri': ['C0024485'],
#  'mra': ['C0243032'],
#  'rl': ['C1840023'],
#  'eeg': ['C0013819'],
#  'pcas': ['C0149576'],
#  'mi': ['C0027051'],
#  'map': ['C0428886'],
#  'cvp': ['C0199666', 'C1321771', 'C0428640'],
#  'sbps': ['C1306620'],
#  'esr': ['C1176468'],
#  'crp': ['C0201657'],
#  'nos': ['C1518425'],
#  'orif': ['C1297885'],
#  'xrt': ['C0436209'],
#  'peg': ['C0176751'],
#  'chemo': ['C0184613', 'C0392920'],
#  'abx': ['C0003232'],
#  'pta': ['C2936666', 'CUI-less'],
#  'ns': ['C0445115', 'C0028081'],
#  'id': ['C1555764', 'C0152277'],
#  'mrsa': ['C0343401', 'C1265292'],
#  'cb': ['C0231242'],
#  'plt': ['C0005821'],
#  'taxol': ['CUI-less'],
#  'cddp': ['C0008838'],
#  'do': ['C0012634'],
#  'sz': ['C0036572'],
#  'trach': ['C1875833', 'C0184159', 'C0040590', 'C1579582', 'C0040591'],
#  'otw': ['CUI-less'],
#  'i': ['C0205266', 'C2228468'],
#  'ap': ['C1999039', 'C1827496'],
#  'pa': ['C1996865', 'C0034052', 'C0428642'],
#  'esbl': ['C3264059'],
#  'tf': ['CUI-less'],
#  'creat': ['C0201975'],
#  'onc': ['C0740692', 'C0085118'],
#  'cont': ['CUI-less', 'C0549178', 'C3494713', 'C0584669'],
#  'lft': ['C0023901'],
#  'tpa': ['CUI-less'],
#  'o2sat': ['C0523807'],
#  'tox': ['C0040541'],
#  'ed': ['C0562508'],
#  'tachy': ['C0039231'],
#  'ck': ['C0010287', 'C0201973', 'C0008415'],
#  'ckmb': ['C0523584'],
#  'mb': ['C0010290'],
#  'rca': ['C1261316'],
#  '5vcabg': ['C0396789'],
#  'sscp': ['C0151826', 'C0742310'],
#  'ste': ['C0520886'],
#  'std': ['C0520887'],
#  'd1': ['C0524430', 'C0447056'],
#  'lima': ['C0447054'],
#  'om1': ['C0226040', 'C0524434'],
#  '3vd': ['C3272265', 'CUI-less'],
#  'co': ['C0007165'],
#  'ci': ['C0428776'],
#  'ivdu': ['C0699778'],
#  'neck': ['C2228463'],
#  'cvs': ['C0436125'],
#  'hs': ['C0018820'],
#  'a': ['C0221464'],
#  'v': ['C0348013', 'C2228490', 'C0042963'],
#  'pl': ['C0332195'],
#  'rvedp': ['C0456183'],
#  'pcw': ['C0086879'],
#  'cw': ['C0332290', 'C0231242'],
#  '5v': ['CUI-less'],
#  'stemi': ['C1303258'],
#  'bgs': ['C0428554'],
#  'bid': ['C0585361', 'CUI-less'],
#  'qd': ['C0332173'],
#  'acs': ['C0948089'],
#  'copd': ['C0024117'],
#  'biba': ['CUI-less'],
#  'nh': ['C0028688'],
#  'adls': ['C0001288'],
#  'adl': ['C0001288'],
#  'extr': ['C0436150'],
#  'cmo': ['C0150521', 'C0030231'],
#  'ngt': ['C0085678'],
#  'ng': ['C0085678', 'C3282907'],
#  'o2sats': ['C0523807'],
#  'hpi': ['C0262512'],
#  'ace': ['C0201888'],
#  'psv': ['C2223980'],
#  'ac': ['C2223981'],
#  'ds': ['CUI-less'],
#  'nph': ['C0021658'],
#  'cicu': ['C0587446'],
#  'polys': ['C1168338', 'C0032594'],
#  'vent': ['C1522565', 'C0035203'],
#  'rchop': ['CUI-less'],
#  'pet': ['C0032743'],
#  'dx': ['C0011900'],
#  'niddm': ['C0011860'],
#  'ppd': ['C0750582', 'C0034131'],
#  'extrem': ['C0436150'],
#  'dsf': ['CUI-less'],
#  'moyb': ['CUI-less'],
#  'iii': ['C2228464'],
#  'vi': ['C2228416'],
#  'eoms': ['CUI-less'],
#  'vii': ['C2228441'],
#  'viii': ['C2228510'],
#  'ix': ['C2228445'],
#  'x': ['C2228508'],
#  'xi': ['C2228484'],
#  'scm': ['C0224153'],
#  'dtrs': ['C0489815'],
#  'rams': ['CUI-less'],
#  'dcd': ['C0030685', 'C1444662'],
#  'sda': ['C0018817'],
#  'pfo': ['C0016522'],
#  'asd': ['C0018817'],
#  'la': ['C0225860'],
#  'lvot': ['C0225912'],
#  'vsd': ['C0018818'],
#  'as': ['C0003507'],
#  'ar': ['C0003504'],
#  'mvp': ['C0026267'],
#  'pr': ['C0034088'],
#  '6mp': ['C0000618'],
#  'pco2': ['C1269842'],
#  'po2': ['C0202155'],
#  'ldh': ['C0022917', 'C0202113'],
#  'mcv': ['C0524587'],
#  'tibc': ['C0036835'],
#  'lfts': ['C0023901'],
#  'alt': ['C0001899', 'C0201836'],
#  'ast': ['C0004002', 'C0201899'],
#  'cc': ['C0277786'],
#  'nrb': ['C1960093'],
#  'hcvab': ['C0166049'],
#  'inh': ['C0022209'],
#  'inpt': ['C0021562'],
#  'detox': ['C1511794'],
#  'sat': ['C0523807', 'C0513686'],
#  'hennt': ['C3494720'],
#  'ama': ['C2919670'],
#  'si': ['C2364109'],
#  'ppx': ['C0199176'],
#  'sc': ['C0443315', 'C1550302'],
#  'dispo': ['C0743223'],
#  'iga': ['C0020835'],
#  'ttp': ['CUI-less'],
#  'bka': ['C0002692'],
#  'or': ['C0029064'],
#  'hd': ['C0019004'],
#  'recs': ['C0034866'],
#  'npo': ['C0419179'],
#  'pos': ['C0205531', 'C1446409', 'C0518037'],
#  'who': ['C0332119'],
#  'cop': ['C0024117'],
#  'pvd': ['C0085096', 'C0034087'],
#  'aaa': ['C0162871'],
#  'mngmt': ['C1273870'],
#  'resp': ['C0521346', 'C0599324'],
#  'ems': ['C0013961'],
#  'nebs': ['C1300458'],
#  'bipap': ['C1458059'],
#  'ntg': ['C0028158'],
#  'hep': ['C0019134'],
#  'paf': ['C0032172', 'C0235480'],
#  'brady': ['C0428977'],
#  'tob': ['C0040329', 'C0453996'],
#  'lat': ['C0205093'],
#  'xfered': ['C0030704'],
#  'mvh': ['CUI-less'],
#  'hf': ['C0018801'],
#  'probnp': ['C0669479'],
#  'dcmeds': ['C0489553'],
#  'nitro': ['C0017887'],
#  'tia': ['C0007787'],
#  'eval': ['C0220825'],
#  'dz': ['C0012634'],
#  'to': ['C0041275'],
#  'ica': ['C0007276'],
#  'sig': ['C0750502'],
#  'arf': ['C0022660', 'C0264490'],
#  'na': ['C0037473', 'C0524661', 'C1272460'],
#  'neuropsych': ['C0027902'],
#  'csu': ['C1631606', 'CUI-less'],
#  'coag': ['C0201122'],
#  'staph': ['C0038160'],
#  'cbc': ['C0009555'],
#  'q': ['C1720374'],
#  'satting': ['C0523807'],
#  'qhs': ['C1275563'],
#  'ldl': ['C0202117', 'C0023823'],
#  'tr': ['C0040961'],
#  'fluoro': ['C0016356'],
#  'hepc': ['C0019196'],
#  'cea': ['C0014099'],
#  'alc': ['C0001948'],
#  'ao': ['CUI-less'],
#  'atnc': ['CUI-less'],
#  'vre': ['C1265175'],
#  'upj': ['C0227680'],
#  'ebl': ['C1443559'],
#  '3u': ['C0439184'],
#  'simv': ['C0278335'],
#  'pm': ['C0030163'],
#  'vv1': ['CUI-less'],
#  'vtach': ['C0042514'],
#  'nsvt': ['C2919575', 'C0750194'],
#  'outpt': ['C0029921'],
#  'fxn': ['C0542341'],
#  'jp': ['C1272738'],
#  'fu': ['C1522577'],
#  'cpap': ['C0199451'],
#  'vss': ['C0277803', 'CUI-less'],
#  'ble': ['C1720201', 'CUI-less'],
#  'adf': ['C0231771'],
#  'apf': ['CUI-less'],
#  'fhl': ['C0224473'],
#  'l2': ['C0446433'],
#  'prbcs': ['C2316467'],
#  'heme': ['C0587491', 'C0475180'],
#  'cs': ['C0009818'],
#  'oob': ['C2135950', 'C2987219'],
#  'tlso': ['C2014886'],
#  'appt': ['C0003629'],
#  'tvi': ['C0808380'],
#  'ee': ['C1275825'],
#  'pcwp': ['C0034094', 'C0086879'],
#  'hypo': ['C0086439'],
#  'aids': ['C0001175'],
#  'hcv': ['C0220847'],
#  'ptsd': ['C0038436'],
#  'gcs': ['C0017594'],
#  'ro': ['C0332196'],
#  'cspine': ['C0728985'],
#  'fx': ['C0016658'],
#  'c34': ['C0446413'],
#  'c45': ['C0446414'],
#  'c56': ['C0446415'],
#  'c67': ['C0446416'],
#  'pea': ['C1960149'],
#  'vf': ['C0042510'],
#  'ards': ['C2362319'],
#  'ivda': ['C0086181'],
#  'ca': ['C0006826'],
#  'eomexam': ['C2228439'],
#  'ett': ['C0336630', 'C0430507'],
#  'stim': ['C1292856', 'C1948023'],
#  'br': ['CUI-less'],
#  'tri': ['CUI-less'],
#  'pat': ['CUI-less'],
#  'ach': ['CUI-less'],
#  'fsbg': ['C2022094'],
#  'wd': ['C2051419'],
#  'wn': ['C2051421'],
#  'doa': ['C2215405'],
#  'om2': ['C0524435', 'C0447061'],
#  'lvedp': ['C0456190'],
#  'usoh': ['CUI-less'],
#  'n': ['C0027497'],
#  'tech': ['C0554178'],
#  'lcx': ['C1305727'],
#  'midrca': ['C3472627'],
#  'ffr': ['C1721077'],
#  'iabp': ['C0021860', 'C0702122'],
#  'syst': ['C0039155'],
#  'pcis': ['C1532338'],
#  'hyperchol': ['C0020443'],
#  'cardio': ['C0007226'],
#  'nstemi': ['C1561921'],
#  'pvcs': ['C0151636'],
#  'anticoag': ['C0003280'],
#  'ckd': ['C1561643'],
#  'k': ['C0202194', 'C0032821'],
#  '60amp': ['C0457243'],
#  'epi': ['C0014563'],
#  'bicarb': ['C0074722'],
#  'x1amp': ['C0179031'],
#  'd50': ['C0770264'],
#  'reg': ['C0205272'],
#  'esrd': ['C2316810', 'C0022661'],
#  'pw': ['C0277786'],
#  'rbb': ['C0225916'],
#  'pmhx': ['C0455458'],
#  'ge': ['C0744316'],
#  'aaox3': ['C1961840'],
#  'hh': ['C3489393'],
#  'ppi': ['C0358591'],
#  'ugi': ['C0041909', 'C3203348'],
#  'ivfs': ['C1289919'],
#  'mets': ['C2939420'],
#  'net': ['C0206093'],
#  'tx': ['C1522326'],
#  'c2': ['C0446412'],
#  'afeb': ['C0004238'],
#  'llsb': ['C2230293'],
#  'neuroonc': ['C1518288'],
#  'u': ['C0439148'],
#  'anc': ['C0948762'],
#  'nkda': ['C0262581'],
#  'lvh': ['C0149721'],
#  'og': ['C0450104'],
#  'benzos': ['C0005064'],
#  'barb': ['C0004745'],
#  'bil': ['C0238767'],
#  'agap': ['C0003074'],
#  'osa': ['C0520679'],
#  'shx': ['C0424945'],
#  'hx': ['C0019664', 'C0262926'],
#  'detoxes': ['C0150543'],
#  'temp': ['C0039476', 'C0578034'],
#  'peep': ['C0032740'],
#  'bpm': ['C0439385'],
#  'dec': ['C0205216'],
#  'rep': ['C0521346'],
#  'ps': ['C0419008'],
#  'sats': ['C0523807'],
#  'od': ['C0029944'],
#  'ogt': ['C0442472'],
#  'aa': ['C0001972'],
#  'comm': ['C1705415', 'C0009452'],
#  'ce': ['C2024853'],
#  'pk': ['C1999262'],
#  'rhf': ['C0235527'],
#  'fem': ['C0232148'],
#  'ldp': ['C2366896'],
#  'rdp': ['C0834665'],
#  'pad': ['C0428644'],
#  'bblockers': ['C0741468'],
#  'poss': ['C0332149'],
#  'asp': ['C0004030'],
#  't1': ['CUI-less'],
#  'stir': ['CUI-less'],
#  'sr': ['C0039155'],
#  'mibi': ['C1142219', 'C0203713'],
#  'nr': ['C0086715', 'C0442740'],
#  'lusb': ['C2230287'],
#  'card': ['C0436125'],
#  'cpb': ['C0007202'],
#  'lm': ['C0447054'],
#  'cns': ['C0850976'],
#  'orl': ['CUI-less'],
#  'pmns': ['C1317636'],
#  'rcia': ['CUI-less'],
#  'ctangio': ['CUI-less'],
#  'rc': ['C1261316'],
#  'cri': ['C0403447'],
#  'is': ['C0428776'],
#  'os': ['C0007165', 'CUI-less'],
#  's4': ['C0232240', 'C0232241'],
#  'igga': ['CUI-less'],
#  'et': ['C0599554'],
#  'bg': ['C0392201'],
#  'fbs': ['C2825162'],
#  'llq': ['C0439737'],
#  'igf2': ['C0021666'],
#  'brbpr': ['C0018932'],
#  'ha': ['C0018681'],
#  's': ['C0038984'],
#  'fh': ['C0241889'],
#  'ab': ['C0562238'],
#  'aandox3': ['C1961840'],
#  'dmii': ['C0011860'],
#  'q2h': ['C0585322'],
#  'q1hour': ['CUI-less'],
#  'igf1': ['C0021665'],
#  'dm2': ['C0011860'],
#  'cme': ['CUI-less'],
#  'spep': ['C0201720'],
#  'upep': ['C0749945'],
#  'aicd': ['C0972395'],
#  'om': ['C0226040'],
#  'tcu': ['CUI-less'],
#  'acls': ['C0887907'],
#  'vfib': ['C0042510'],
#  'ivp': ['C0021440'],
#  'lgh': ['CUI-less'],
#  'avg': ['C0428905'],
#  'scd': ['C0085298'],
#  'exp': ['C1704631'],
#  'vifib': ['C0042510'],
#  'pci': ['C1532338'],
#  'pao2': ['C1822073'],
#  'ngtd': ['C0445119'],
#  'oms': ['C0260272'],
#  'ugib': ['C0041909'],
#  'sq': ['C0443315'],
#  'hob': ['C2709195'],
#  'hcp': ['CUI-less'],
#  'pth': ['C0030520'],
#  'pthrp': ['C0070099'],
#  'sah': ['C0038525'],
#  'ficu': ['CUI-less'],
#  'oa': ['CUI-less'],
#  'rue': ['C0230329'],
#  'ecg': ['C0013798'],
#  'ddx': ['C0011906'],
#  'pmi': ['CUI-less'],
#  'des': ['C1322815'],
#  'rfa': ['C0226447'],
#  'rsr': ['CUI-less'],
#  'imi': ['C0340305'],
#  'cvvh': ['C0472684'],
#  'xfer': ['C0030704'],
#  'rvr': ['C0748243'],
#  'bodmc': ['CUI-less'],
#  'sxfree': ['CUI-less'],
#  'af': ['C0004238'],
#  '2': ['C0232230'],
#  'so': ['C1457887'],
#  'sx': ['C1457887'],
#  'timi1': ['C3272285'],
#  'lr': ['C0439757'],
#  'h': ['C0085508'],
#  'mvo2': ['C0428863'],
#  'gib': ['C0017181'],
#  'aocd': ['C0002873'],
#  'hpyloru': ['C0079488'],
#  'uti': ['C0042029'],
#  'rsfa': ['C0815383'],
#  'sfa': ['C0447106'],
#  'ai': ['C0003504'],
#  'ivc': ['C0042458'],
#  'mrv': ['CUI-less'],
#  'cmv': ['C0010825'],
#  'rap': ['C0456165'],
#  'st': ['C0242823'],
#  'icd': ['C0162589'],
#  'cpk': ['C0750860'],
#  'mmp': ['CUI-less'],
#  't9': ['C0446427'],
#  't12': ['C0446430'],
#  'dxd': ['C0011900'],
#  'ot': ['C0587625'],
#  'fm': ['CUI-less'],
#  'cxrs': ['C0039985'],
#  'rica': ['C0226156'],
#  'wt': ['C0043100'],
#  'ht': ['C0489786'],
#  'mrg': ['CUI-less'],
#  'b': ['C0238767'],
#  'cce': ['CUI-less'],
#  'apd': ['C0339662'],
#  'fe': ['C0444509'],
#  'exams': ['C0582103'],
#  'fk506': ['C0085149'],
#  'tofk506': ['C0085149'],
#  'p02': ['C0202155'],
#  'emt': ['C0013963'],
#  'ob': ['C0858947'],
#  'dnr': ['C0582114'],
#  'dni': ['C0742532'],
#  'cks': ['C0201973'],
#  'lpl': ['C0524437'],
#  'rpda': ['C2939121'],
#  'dvts': ['C0149871'],
#  't4': ['C0202231'],
#  't3': ['C0428419'],
#  'elev': ['C3163633'],
#  'mssa': ['C3264363'],
#  'rbc': ['C0014772'],
#  'pmn': ['C1317636'],
#  'hypok': ['C0020621'],
#  'rvsysfxn': ['C2024240'],
#  'vit': ['C0042890'],
#  'wnl': ['C0442816'],
#  'ccy': ['C0008320'],
#  's3': ['C0232237'],
#  'aox2': ['CUI-less'],
#  'rll': ['C1261075'],
#  'chol': ['C0201950'],
#  'hosp': ['C0019994'],
#  'ocr': ['C0028860'],
#  'pcxr': ['CUI-less'],
#  'nchct': ['CUI-less'],
#  'osms': ['C0029391'],
#  'lytes': ['C0013832'],
#  'coags': ['C0009117'],
#  'neuroicu': ['C0587448'],
#  'ich': ['C2937358']}

# %%
test_unseen_groups = []
for abbr_group, cuis in test_group_cuis_dict.items():
    if abbr_group not in train_group_cuis_dict:
        test_unseen_groups.append(abbr_group)
print(f'{len(test_unseen_groups)} abbr groups are not seen in the training set')        

group_snum_counter = Counter([len(v) for k, v in test_group_cuis_dict.items()])
print(f'Number of senses in test set (all): {group_snum_counter}')

group_snum_counter = Counter([len(v) for k, v in test_group_cuis_dict.items() if k in train_group_cuis_dict])
print(f'Number of senses in test set (abbrs in train): {group_snum_counter}')
# Out:
# 326 abbr groups are not seen in the training set
# Number of senses in test set (all): Counter({1: 568, 2: 107, 3: 21, 4: 3, 5: 3, 6: 2})
# Number of senses in test set (abbrs in train): Counter({1: 266, 2: 85, 3: 19, 4: 3, 5: 3, 6: 2})

# %%
# For all test abbreviation -> Find possible labels
test_unseen_umls_labels = []
for abbr_group in test_group_cuis_dict:
    for abbr in umls_abbr_denorm_dict[abbr_group]:
        for abbr_eui in umls_abbr_eui_dict[abbr]:
            for label_eui in umls_abbr_expansion_dict[abbr_eui]:
                test_unseen_umls_labels.extend(umls_eui_name_dict[label_eui])
test_unseen_umls_labels = list(set(test_unseen_umls_labels))  # Remove duplicates
test_unseen_umls_labels = [l for l in test_unseen_umls_labels if all([ord(c) < 128 for c in l])]  # Only alpha-numeric

print(f'{len(test_unseen_umls_labels)} labels found from LRABR and to be mapped by MetaMap')
print(test_unseen_umls_labels[:20])
# Out:
# 9717 labels found from LRABR and to be mapped by MetaMap
# ['ptaquiloside', 'somatic cell hybrid', 'epichlorohydrin', 'watt', 'cyclic adenosine monophosphate-response element', 'supra-chiasmatic', 'metabolic index', 'retrograde pyelogram', 'Rhizomucor miehei lipase', 'osteopetrosis', 'wall thickening', 'endoperoxide', 'thoracolumbosacral orthosis', 'heat-stable', 'ectopic focus', 'nervous system', 'organising pneumonia', 'ammoniumsulphate', 'low-responder', 'catechol oestrogen']

# %%
# Map possible labels into CUIs using Metamap
mm_infpath = os.path.join(sc13t2_dir, 'umls_expansions.txt')
mm_outfpath = os.path.join(sc13t2_dir, 'mm_output.txt')

# %%
with open(mm_infpath, 'w', encoding='utf-8') as fd:
    fd.write('\n\n'.join(test_unseen_umls_labels)+'\n')  # 2 line spacing for metamap process

# %% [markdown]
# - Please run Metamap (2018AB version) with following command on `data/sc13t2`:
# ```!metamap -z -I umls_expansions.txt mm_output.txt```

# %%
# Parsing Metamap output: CUI-label mapping
with open(mm_outfpath, 'r') as fd:
    lines = [l.strip() for l in fd.readlines()]

mm_label_cui_dict = {}
i = 0
while i < len(lines):
    l = lines[i]
    if l.startswith("Phrase: "):
        label = l[8:]  # After "Phrase: "
        label_lower = label.lower()
        while i < len(lines)-1:
            i += 1
            l = lines[i]
            if not l: break
            elif l.startswith("Meta Mapping"):
                i += 1
                l = lines[i]
                name = l[l.index(":")+1:l.rindex("[")].strip()
                name_lower = name.lower().replace(" ", "")
                if all([(w in name_lower) for w in label_lower.split(" ")]):
                    cui = l[l.index(":")-8:l.index(":")]
                    mm_label_cui_dict[label] = cui
#                     print(f'{label}: {name} ({cui})')
                    break
    i += 1

mm_cui_label_dict = {cui:label for label, cui in mm_label_cui_dict.items()}
print(f'{len(mm_cui_label_dict)} labels mapped to CUI')
# Out:
# 4083 labels mapped to CUI

# %%
# Show some mappings
print('\n'.join([f'({cui}) {label}' for cui, label in list(mm_cui_label_dict.items())[:10]]))
# Out:
# (C0072576) ptaquiloside
# (C0020200) somatic cell hybrid
# (C0014486) epichlorohydrin
# (C0439261) watt
# (C0203110) retrograde pyelogram
# (C0029454) osteopetrosis
# (C0027763) nervous system
# (C0264383) organising pneumonia
# (C0002620) ammonium sulphate
# (C0083727) neurogranin

# %%
# Test unseen abbr group -> LRABR CUIs
test_unseen_group_cuis_dict = defaultdict(set)
for abbr_group in test_unseen_groups:
    for abbr in umls_abbr_denorm_dict[abbr_group]:
        for abbr_eui in umls_abbr_eui_dict[abbr]:
            for label_eui in umls_abbr_expansion_dict[abbr_eui]:
                labels = umls_eui_name_dict[label_eui]
                cuis = [mm_label_cui_dict[label] for label in labels if label in mm_label_cui_dict]
                if cuis:
                    test_unseen_group_cuis_dict[abbr_group].update(cuis)
test_unseen_group_cuis_dict = {k:list(v) for k, v in test_unseen_group_cuis_dict.items()}
print(f'{len(test_unseen_group_cuis_dict)} unseen abbr groups mapped to {sum(map(len,test_unseen_group_cuis_dict.values()))} CUIs')
max_label_num = max(map(len, test_unseen_group_cuis_dict.values()))
print(f'Up to {max_label_num} candidates')
# Out:
# 214 unseen abbr groups mapped to 1323 CUIs
# Up to 50 candidates

# %%
list(test_unseen_group_cuis_dict.items())[:5]
# Out:
# [('gb', ['C0005304', 'C4321287', 'C1960832', 'C0016976']),
#  ('uop', ['C0232856']),
#  ('bnp', ['C0054015']),
#  ('cr',
#   ['C1547104',
#    'C0009069',
#    'C0007443',
#    'C0234176',
#    'C0868939',
#    'C0391908',
#    'C0555952',
#    'C0677874',
#    'C3842377',
#    'C0039985',
#    'C0419011',
#    'C0010294',
#    'C2981152',
#    'C0232187',
#    'C2936352',
#    'C1135809',
#    'C0034793',
#    'C0008972',
#    'C2930544',
#    'C0007702',
#    'C0009647',
#    'C0436307',
#    'C0008574',
#    'C0009742',
#    'C0034936']),
#  ('bx', ['C0185298', 'C0005558'])]

# %%
# Test data output (All test abbr + CUIs augmented from LRABR)
num_train = max(8, max_label_num)
cnt = 0
cnt_unseen = 0
example_snum_counter = Counter()
with open(test_output_fpath, 'w', encoding='utf-8') as f_out:
    writer = csv.writer(f_out, delimiter='\t', quotechar=None)
    writer.writerow(['index', 'group', 'left', 'right', 'label'] + [f'train_{i}' for i in range(num_train)])
    for d in test_examples:
        abbr, left, right, cui = d
        abbr_group = normalize_abbr_variation(abbr)
        if (not abbr_group in train_group_cuis_dict):  #  We cannot get this if the abbr is not in training set
            if abbr_group in test_unseen_group_cuis_dict:
                train_cuis = test_unseen_group_cuis_dict[abbr_group]
#                 print((abbr_group, train_cuis))
            else:
                cnt_unseen += 1
                train_cuis = []
        else:
            train_cuis = train_group_cuis_dict[abbr_group]
        test_cuis = test_group_cuis_dict[abbr_group]
#         cuis = test_group_cuis_dict[abbr_group]
        example_snum_counter[len(test_cuis)] += 1
        writer.writerow([cnt, abbr, left, right, cui] + train_cuis + [''] * (num_train - len(train_cuis)))
        cnt += 1

# %%
print(f'{cnt_unseen} test examples are not in the training set')
# Out:
# 166 test examples are not in the training set

# %% [markdown]
# ### 3. CUI-label

# %%
print(f'Write test(training+LRABR) CUI-label list to {cui_label_fpath}')
with open(cui_label_fpath, 'w', encoding='utf-8') as f_out:
    writer = csv.writer(f_out, delimiter='\t', quotechar=None)
    writer.writerow(['cui', 'label'])
    for cui, labels in train_cui_labels_dict.items():
        writer.writerow([cui, labels[0]])
    for cui, label in mm_cui_label_dict.items():
        if cui not in train_cui_labels_dict:
            writer.writerow([cui, label])
# Out:
# Write test(training+LRABR) CUI-label list to ../data/sc13t2/cui_label.tsv

# %% [markdown]
# ## Data statistics

# %% [markdown]
# - Abbreviation

# %%
abbr_var_set_train = set(list(zip(*train_examples))[0])
print(f'{len(abbr_var_set_train)} training abbr variations')

abbr_var_set_test = set(list(zip(*test_examples))[0])
print(f'{len(abbr_var_set_test)} test abbr variations')

print(f'{len(abbr_var_set_train | abbr_var_set_test)} total abbr variations')
# Out:
# 843 training abbr variations
# 871 test abbr variations
# 1285 total abbr variations

# %% [markdown]
# - Abbreviation groups

# %%
abbr_group_set_train = set([normalize_abbr_variation(abbr) for abbr in list(zip(*train_examples))[0]])
print(f'{len(abbr_group_set_train)} training abbr groups')

abbr_group_set_test = set([normalize_abbr_variation(abbr) for abbr in list(zip(*test_examples))[0]])
print(f'{len(abbr_group_set_test)} test abbr groups')

print(f'{len(abbr_group_set_train | abbr_group_set_test)} total abbr groups')
# Out:
# 670 training abbr groups
# 704 test abbr groups
# 996 total abbr groups

# %% [markdown]
# - Labels (CUIs)

# %%
cui_group_set_train = set(list(zip(*train_examples))[3])
print(f'{len(cui_group_set_train)} training cuis')

cui_group_set_test = set(list(zip(*test_examples))[3])
print(f'{len(cui_group_set_test)} test cuis')
    
print(f'{len(cui_group_set_train | cui_group_set_test)} total cuis')
# Out:
# 697 training cuis
# 707 test cuis
# 1058 total cuis

# %% [markdown]
# ## Random & Majority accuracies

# %%
train_abbr_cuis = defaultdict(list)

with open(train_output_fpath, 'r') as fd:
    reader = csv.reader(fd, delimiter='\t', quotechar=None)
    for i, line in enumerate(reader):
        if i == 0:
#             print(line)
            abbr_idx = line.index('group')
            label_idx = line.index('label')
            continue
        abbr = line[abbr_idx]
        label = line[label_idx]
        train_abbr_cuis[normalize_abbr_variation(abbr)].append(label)
        
train_majority_cuis = {}
for abbr, cuis in train_abbr_cuis.items():
    counter = Counter(cuis)
    train_majority_cuis[abbr] = counter.most_common()[0][0]

# %%
test_total_cnt = 0
test_majority_cnt = 0
test_random_cnt = 0

with open(test_output_fpath, 'r') as fd:
    reader = csv.reader(fd, delimiter='\t', quotechar=None)
    for i, line in enumerate(reader):
        if i == 0:
#             print(line)
            abbr_idx = line.index('group')
            label_idx = line.index('label')
            continue
        abbr = line[abbr_idx]
        label = line[label_idx]
        cands = []
        for j in range(label_idx+1, len(line)):
            if line[j]:
                cands.append(line[j])
        
        test_total_cnt += 1
        if label in cands:
            test_random_cnt += 1.0/len(cands)
        if normalize_abbr_variation(abbr) in train_majority_cuis and \
                    train_majority_cuis[normalize_abbr_variation(abbr)] == label:
            test_majority_cnt += 1

# %%
print(test_total_cnt)
print(test_majority_cnt)
print(test_random_cnt)

print(f'Random  : {test_random_cnt/test_total_cnt}')
print(f'Majority: {test_majority_cnt/test_total_cnt}')
# Out:
# 3774
# 2614
# 2100.0549575423483
# Random  : 0.5564533538797956
# Majority: 0.6926338102808691

# %% [markdown]
# ---- For debug ----

# %%
old_test_examples = list(csv.reader(open('/home/juyongk/workspace/temp/NCBI-BERT_aws_backup/abbr/sc13t2_lrabr/test.tsv'), delimiter='\t', quotechar=None))[1:]
len(old_test_examples)
# Out:
# 3774

# %%
new_test_examples = list(csv.reader(open(test_output_fpath), delimiter='\t', quotechar=None))[1:]
len(new_test_examples)
# Out:
# 3774

# %%
def sort_examples(examples):
    temp_list = [tuple(e[1:2] + sorted(e[4:]) + [i]) for i, e in enumerate(examples)]
    temp_list.sort()
    return [examples[t[-1]] for t in temp_list]

# %%
old_test_examples = sort_examples(old_test_examples)
new_test_examples = sort_examples(new_test_examples)

for i, (e1, e2) in enumerate(zip(old_test_examples, new_test_examples)):
    if i == 3140: continue
    if e1[1:2] + sorted(e1[4:]) != e2[1:2] + sorted(e2[4:-1]):
        break

# %%
i
# Out:
# 156

# %%
list(zip(e1, e2))
# Out:
# [('3572', '206'),
#  ('AV-block', 'AV-block'),
#  ('seen on single view chest examination. Brief Hospital Course: Mr.  was admitted the morning of 4/27 and proceeded directly to the operating room. He underwent a mitral valve repair with resection of the posterior leaflet with a 28 mm DIETRICK band with Dr. Prof FRANKIN. Please see OP note for full details. He was successfully weened and extubated on his operative evening and was placed on a steroid taper with the help of endocrinology given his addisons disease. On postoperative day two he was transferred to the inpatient telemetry floor for ongoing management and rehabilitation. On postoperative day four he had a burst of atrial fibrillation -- converted spontaneously and was noted to have a first degree',
#   'seen on single view chest examination. Brief Hospital Course: Mr.  was admitted the morning of 4/27 and proceeded directly to the operating room. He underwent a mitral valve repair with resection of the posterior leaflet with a 28 mm MELLEMA band with Dr. Prof MCCULLORS. Please see OP note for full details. He was successfully weened and extubated on his operative evening and was placed on a steroid taper with the help of endocrinology given his addisons disease. On postoperative day two he was transferred to the inpatient telemetry floor for ongoing management and rehabilitation. On postoperative day four he had a burst of atrial fibrillation -- converted spontaneously and was noted to have a first degree'),
#  ('. Due to this AV block, his beta blockade was held. On postoperative day five, with no furtehr episodes of afib but with elevated BP and HR, a low dose beta-blocker was added with no change in his AV block. He also continued to be significantly edamatous, nearly 14 kg up from his pre-op weight and he was actively diureses with lasix. On postoperative days six and seven, we continued to diurese him heavily. Endocrine also continued to follow with regards for his steroid taper. On postoperative eight, he cleared physical therapy and was discahrged home with a visiting nurse to follow. Medications on Admission: Plavix 75 daily. Prednisone 12.5 mg daily. Flurinef 0.1 mg daily. Levoxyl 0.025 mg daily. Enalapril 10 mh bid. Lipitor 20 mg daily.',
#   '. Due to this AV block, his beta blockade was held. On postoperative day five, with no furtehr episodes of afib but with elevated BP and HR, a low dose beta-blocker was added with no change in his AV block. He also continued to be significantly edamatous, nearly 14 kg up from his pre-op weight and he was actively diureses with lasix. On postoperative days six and seven, we continued to diurese him heavily. Endocrine also continued to follow with regards for his steroid taper. On postoperative eight, he cleared physical therapy and was discahrged home with a visiting nurse to follow. Medications on Admission: Plavix 75 daily. Prednisone 12.5 mg daily. Flurinef 0.1 mg daily. Levoxyl 0.025 mg daily. Enalapril 10 mh bid. Lipitor 20 mg daily.'),
#  ('C0004245', 'C0004245'),
#  ('', 'C0004245'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', '')]

# %%
normalize_abbr_variation('AV-block')
# Out:
# 'avblock'

# %%
umls_abbr_denorm_dict['avblock']
# Out:
# ['AV block']

# %%
mm_cui_label_dict['C0004245']
# Out:
# 'atrioventricular block'

# %% [markdown]
# ??!?!
